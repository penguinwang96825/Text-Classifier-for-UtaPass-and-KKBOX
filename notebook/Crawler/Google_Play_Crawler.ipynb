# %%
! pip3 install beautifulsoup4
! pip3 install selenium
! brew install geckodriver
# Out:
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/1d/5d/3260694a59df0ec52f8b4883f5d23b130bc237602a1411fa670eae12351e/beautifulsoup4-4.7.1-py3-none-any.whl (94kB)
#     100% |████████████████████████████████| 102kB 766kB/s a 0:00:01
# Collecting soupsieve>=1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/b9/a5/7ea40d0f8676bde6e464a6435a48bc5db09b1a8f4f06d41dd997b8f3c616/soupsieve-1.9.1-py2.py3-none-any.whl
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.7.1 soupsieve-1.9.1
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting selenium
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# Collecting urllib3 (from selenium)
#   Downloading https://files.pythonhosted.org/packages/81/9b/715e96377cc1f87e71d9d4259c6f88bf561a539622ba3042e73188e0bc2d/urllib3-1.25-py2.py3-none-any.whl (149kB)
#     100% |████████████████████████████████| 153kB 158kB/s ta 0:00:01
# Installing collected packages: urllib3, selenium
# Successfully installed selenium-3.141.0 urllib3-1.25
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Warning: geckodriver 0.24.0 is already installed and up-to-date
# To reinstall 0.24.0, run `brew reinstall geckodriver`

# %%
import time
from bs4 import BeautifulSoup
import sys, io
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.proxy import *
import pandas as pd

# %%
no_of_reviews = 1000
non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

# %%
from selenium.common.exceptions import NoSuchElementException        
def check_exists_by_xpath(xpath):
    try:
        driver.find_element_by_xpath(xpath)
    except NoSuchElementException:
        return False
    return True

temp = {"review": 0, "Author Name": "", "Review Date": "", "Review Ratings": 0, 
        "Review Body": "", "Developer Reply": ""}

def replace_value_with_definition(key_to_find, definition):
    for key in temp.keys():
        if key == key_to_find:
            temp[key] = definition

# %%
driver = webdriver.Chrome(r"./chromedriver")

# %%
wait = WebDriverWait( driver, 10 )

# %%
# Append your app store urls here
urls = ["https://play.google.com/store/apps/details?id=com.kddi.android.UtaPass&hl=ja"]

for url in urls:

    driver.get(url)

    page = driver.page_source

    soup_expatistan = BeautifulSoup(page, "html.parser")

    expatistan_table = soup_expatistan.find("h1", class_="AHFaub")

    print("App name: ", expatistan_table.string)

    expatistan_table = soup_expatistan.findAll("span", class_="htlgb")[4]

    print("Installs Range: ", expatistan_table.string)

    expatistan_table = soup_expatistan.find("meta", itemprop="ratingValue")

    print("Rating Value: ", expatistan_table['content'])

    expatistan_table = soup_expatistan.find("meta", itemprop="reviewCount")

    print("Reviews Count: ", expatistan_table['content'])

    soup_histogram = soup_expatistan.find("div", class_="VEF2C")

    rating_bars = soup_histogram.find_all('div', class_="mMF0fd")

    for rating_bar in rating_bars:
        print("Rating: ", rating_bar.find("span").text)
        print("Rating count: ", rating_bar.find("span", class_="L2o20d").get('title'))

    # open all reviews
    url = url + '&showAllReviews=true'
    driver.get(url)
    time.sleep(5) # wait dom ready
    for i in range(1,25):
        try:
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);') # scroll to load other reviews
            time.sleep(1)
            if check_exists_by_xpath('//*[@id="fcxH9b"]/div[5]/c-wiz/div/div[2]/div/div[1]/div/div/div[1]/div[2]/div[2]/div/content/span'):
                driver.find_element_by_xpath('//*[@id="fcxH9b"]/div[5]/c-wiz/div/div[2]/div/div[1]/div/div/div[1]/div[2]/div[2]/div/content/span').click()
                time.sleep(2)
        except:
            pass

    page = driver.page_source

    soup_expatistan = BeautifulSoup(page, "html.parser")
    expand_pages = soup_expatistan.findAll("div", class_="d15Mdf")
    counter = 1
    
    for expand_page in expand_pages:
        try:
            print("\n===========\n")
            
            print("review：" + str(counter))
            
            print("Author Name: ", str(expand_page.find("span", class_="X43Kjb").text))
            
            print("Review Date: ", expand_page.find("span", class_="p2TkOb").text)
            
            '''
            //didn't find reviewer link
            print("Reviewer Link: ", expand_page.find("a", class_="reviews-permalink")['href'])
            '''
            
            reviewer_ratings = expand_page.find("div", class_="pf5lIe").find_next()['aria-label'];
            reviewer_ratings = reviewer_ratings.split('/')[0]
            reviewer_ratings = ''.join(x for x in reviewer_ratings if x.isdigit())
            print("Reviewer Ratings: ", reviewer_ratings)
            
            '''
            //didn't find review title
            print("Review Title: ", str(expand_page.find("span", class_="review-title").string))
            '''
            
            print("Review Body: ", str(expand_page.find("div", class_="UD7Dzf").text))
            
            developer_reply = expand_page.find_parent().find("div", class_="LVQB0b")
            if hasattr(developer_reply, "text"):
                print("Developer Reply: " + "\n", str(developer_reply.text))
            else:
                print("Developer Reply: ", "")
            
            counter += 1
        except:
            pass
driver.quit()
# Out:
# App name:  うたパス
# Installs Range:  1,000,000+
# Rating Value:  3.4741108417510986
# Reviews Count:  2221
# Rating:  5
# Rating count:  807
# Rating:  4
# Rating count:  459
# Rating:  3
# Rating count:  375
# Rating:  2
# Rating count:  140
# Rating:  1
# Rating count:  440
#
# ===========
#
# review：1
# Author Name:  nami hotta
# Review Date:  2019年4月21日
# Reviewer Ratings:  3
# Review Body:   色んな音楽がありますがもう少し、聴きたい曲があるといいんですけどね！ってことで星３つかなー
# Developer Reply:
#
# ===========
#
# review：2
# Author Name:  勝又和博
# Review Date:  2019年4月19日
# Reviewer Ratings:  5
# Review Body:   いつも楽しんで、おります
# Developer Reply:
#
# ===========
#
# review：3
# Author Name:  小澤佐由里
# Review Date:  2019年4月21日
# Reviewer Ratings:  5
# Review Body:   とても善いです😃
# Developer Reply:
#
# ===========
#
# review：4
# Author Name:  若本昌平
# Review Date:  2019年4月18日
# Reviewer Ratings:  5
# Review Body:   磐梯山(￣▽￣田沼;)と、何で、優しくかた
# Developer Reply:
#
# ===========
#
# review：5
# Author Name:  遠田豊和
# Review Date:  2019年4月20日
# Reviewer Ratings:  1
# Review Body:   なにやってんだか…。 ウィジェットからのmusic(LISMO!)は再生出来るので、重たい『うたパス』のアプリは無効にしてやった。
# Developer Reply:
#
# ===========
#
# review：6
# Author Name:  冨田須美子
# Review Date:  2019年4月19日
# Reviewer Ratings:  1
# Review Body:   あまり使わない、ユーチューブだけでよい。
# Developer Reply:
#
# ===========
#
# review：7
# Author Name:  Googleユーザー
# Review Date:  2019年4月20日
# Reviewer Ratings:  1
# Review Body:   au端末とシムフリー端末で使用。au端末は反応が鈍く曲をタッチしても再生までに十数秒かかる。シムフリー端末はプレイリストの中の音楽が消えていた。lismoの時はこんなトラブルなんて無かったのに。どんどん使いにくくなってる。うたパスはうたパスで提供してlismoプレイヤーも提供して欲しい。今現在　うたパスのプレイヤー以外は使ってないから他の機能なんかは全く知らないけどプレイヤーだけで言うとクソ。他社プレイヤーもいっぱいあるけど　その中でも下位の方だと思う。だってマトモに使えないんだから。
# Developer Reply:
#
# ===========
#
# review：8
# Author Name:  MA CA
# Review Date:  2019年4月18日
# Reviewer Ratings:  2
# Review Body:   起動しても重いし、音楽聞いててもバックグラウンドじゃないからアプリ消したら音楽聞けない。前はバックグラウンドで使えてたから結構愛用してたのに。もういらないです。
# Developer Reply:
#
# ===========
#
# review：9
# Author Name:  ここここ
# Review Date:  2019年4月20日
# Reviewer Ratings:  1
# Review Body:   使いにくいしダウンロードしずらい。無駄な機能が多すぎる。そのくせビデオとかまで再生したりするから余計使いづらい
# Developer Reply:
#
# ===========
#
# review：10
# Author Name:  和崎信子
# Review Date:  2019年4月21日
# Reviewer Ratings:  5
# Review Body:   仕事に入る前に軽く音楽聴くとリズミカルに身体が動きます。聴いていて楽しいわよ❗
# Developer Reply:
#
# ===========
#
# review：11
# Author Name:  狼音牙
# Review Date:  2019年4月22日
# Reviewer Ratings:  1
# Review Body:   LISMOが使えなくなった！早くもどせや！うたパスよりLISMOの方が使いやすい。
# Developer Reply:
#
# ===========
#
# review：12
# Author Name:  にしえみ
# Review Date:  2019年4月23日
# Reviewer Ratings:  2
# Review Body:   「購入した楽曲」を購入順に流れるように聞きたい。今は「購入した楽曲」を聞いても一曲ずつしか聞けなくて、次の曲を聞こうとすると操作が必要になる。
# Developer Reply:
#
# ===========
#
# review：13
# Author Name:  穣長谷
# Review Date:  2019年4月23日
# Reviewer Ratings:  3
# Review Body:   前より使い勝手が良くない。
# Developer Reply:
#
# ===========
#
# review：14
# Author Name:  Googleユーザー
# Review Date:  2019年4月19日
# Reviewer Ratings:  4
# Review Body:   お気に入りにアーティストがないのが残念
# Developer Reply:
#
# ===========
#
# review：15
# Author Name:  小澤敏彦
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   うたパスは、なくてはならないアプリです！
# Developer Reply:
#
# ===========
#
# review：16
# Author Name:  三浦宏真
# Review Date:  2019年4月22日
# Reviewer Ratings:  2
# Review Body:   いってあてた
# Developer Reply:
#
# ===========
#
# review：17
# Author Name:  家事直喜
# Review Date:  2019年4月19日
# Reviewer Ratings:  1
# Review Body:   使い難い
# Developer Reply:
#
# ===========
#
# review：18
# Author Name:  Dargelin Tharbo 22
# Review Date:  2019年4月22日
# Reviewer Ratings:  5
# Review Body:   歌詞表示以外は不満なし。
# Developer Reply:
#
# ===========
#
# review：19
# Author Name:  まぁくろ
# Review Date:  2019年4月22日
# Reviewer Ratings:  5
# Review Body:   聞きやすい！
# Developer Reply:
#
# ===========
#
# review：20
# Author Name:  ゆたによう
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   なし
# Developer Reply:
#
# ===========
#
# review：21
# Author Name:  佐藤太郎丸
# Review Date:  2019年4月22日
# Reviewer Ratings:  4
# Review Body:   最高！
# Developer Reply:
#
# ===========
#
# review：22
# Author Name:  田中聡
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   素敵💖
# Developer Reply:
#
# ===========
#
# review：23
# Author Name:  みるく
# Review Date:  2019年4月18日
# Reviewer Ratings:  1
# Review Body:   アップデートしたらLISMOが使えなくうたパスのみになってました。 皆さんと同意見でただただ、使いづらいです。 LISMOに戻して欲しい。 正直、評価もしたくないです。
# Developer Reply:
#
# ===========
#
# review：24
# Author Name:  北尾康太
# Review Date:  2019年4月4日
# Reviewer Ratings:  2
# Review Body:   取り放題の曲数と種類に関しては、まあこの程度かと納得。操作性に関してはイマイチ。プレイリストが簡単にできるところは評価しても良いけど、通信が途切れたりすると、いちいちログインしなきゃなんないし、勝手に取り放題の曲がなくなっていたりする…。この辺をもう少しなんとかして欲しい。
# Developer Reply:
#
# ===========
#
# review：25
# Author Name:  Takashi Yoshida
# Review Date:  2019年4月15日
# Reviewer Ratings:  2
# Review Body:   聴き放題は利用していないので、主にプレイヤーとしての評価です。 ■好きなところ ・デザインがそこそこお洒落 ・歌詞が見れる ・楽曲やアルバム等の一覧が読み仮名でソートされる ■嫌いなところ ・アルバム一覧、アーティスト一覧では読み仮名を編集してもソート順に反映されない (最初から入っていたものだけ有効) ・一時的な再生リストを作れない (アルバム内の1曲だけ再生、みたいなことが面倒) ・現在何のリストを再生中なのかが分かりにくい
# Developer Reply:
#
# ===========
#
# review：26
# Author Name:  toi moko
# Review Date:  2019年4月15日
# Reviewer Ratings:  1
# Review Body:   本当にうたパスとLISMOを統合したのに、疑問に思う。LISMOは、使いやすかった、ロードは、短いし、保存指定も出来ました。うたパスは、ロードが長く、保存指定が、出来ない。うたパスを担当してるかたは、見てるのかどうか疑問に思います。最近では、金儲けだけで、ユーザーの声を無視してるんじゃないかと、見かけます。
# Developer Reply:
#
# ===========
#
# review：27
# Author Name:  ぜっと
# Review Date:  2019年4月8日
# Reviewer Ratings:  2
# Review Body:   アーティスト名を検索しても出て来なかったりします。storeの方で検索するとすぐ出るのにうたパスではなんで出てこんの？意味がわからん？
# Developer Reply:
#
# ===========
#
# review：28
# Author Name:  霧島しま
# Review Date:  2019年4月5日
# Reviewer Ratings:  1
# Review Body:   LISMOに戻して お願いだからLISMOプレイヤーに戻して欲しいです。本当に使いづらい
# Developer Reply:
#
# ===========
#
# review：29
# Author Name:  関口剛史
# Review Date:  2019年4月5日
# Reviewer Ratings:  1
# Review Body:   まったく使えない、使いづらい。はやくLISMOに戻せ
# Developer Reply:
#
# ===========
#
# review：30
# Author Name:  アッキー
# Review Date:  2019年4月8日
# Reviewer Ratings:  3
# Review Body:   純粋に購入した曲をすぐ聞きたいけど、操作がまどろっこしいし、わかりにくいので、LISMOはストアのみ使用、他のアプリで聞いてますが、歌詞がなく不便。
# Developer Reply:
#
# ===========
#
# review：31
# Author Name:  としか
# Review Date:  2019年4月11日
# Reviewer Ratings:  1
# Review Body:   LISMOの方が良かったです ライブラリ無くなったのは最悪 使いにくい
# Developer Reply:
#
# ===========
#
# review：32
# Author Name:  山中治代
# Review Date:  2019年4月5日
# Reviewer Ratings:  4
# Review Body:   古いロックの曲があって、今すごくはまっています。もっと曲数があると、星５個です。
# Developer Reply:
#
# ===========
#
# review：33
# Author Name:  shin sasaki
# Review Date:  2019年4月13日
# Reviewer Ratings:  4
# Review Body:   日本語の歌が充実している。コスパいいし、歌詞見ながら本人の声で曲を聞けるから、カラオケの練習にもなる。
# Developer Reply:
#
# ===========
#
# review：34
# Author Name:  Suzu
# Review Date:  2019年4月15日
# Reviewer Ratings:  1
# Review Body:   昔のLISMO!の方がプレイヤーとしては使いやすかった‥…(´･ω･`)
# Developer Reply:
#
# ===========
#
# review：35
# Author Name:  木坂昌司
# Review Date:  2019年4月5日
# Reviewer Ratings:  5
# Review Body:   ツーリングに良く聞いて✨😆👂います。
# Developer Reply:
#
# ===========
#
# review：36
# Author Name:  家永由里子
# Review Date:  2019年4月10日
# Reviewer Ratings:  5
# Review Body:   いつも利用しています。
# Developer Reply:
#
# ===========
#
# review：37
# Author Name:  高橋孝幸
# Review Date:  2019年4月9日
# Reviewer Ratings:  1
# Review Body:   アンインストールできない
# Developer Reply:
#
# ===========
#
# review：38
# Author Name:  矢島香
# Review Date:  2019年4月11日
# Reviewer Ratings:  5
# Review Body:   月額がもったいないとなる月がないくらい使い込んでいる。家事に、寝る前に、無心でいたいときに。便利です。
# Developer Reply:
#
# ===========
#
# review：39
# Author Name:  しらねしょうじ
# Review Date:  2019年4月7日
# Reviewer Ratings:  5
# Review Body:   楽しく過ごしています。
# Developer Reply:
#
# ===========
#
# review：40
# Author Name:  立木美代子
# Review Date:  2019年4月6日
# Reviewer Ratings:  4
# Review Body:   好きな時に好きな歌が聴ける
# Developer Reply:
#
# ===========
#
# review：41
# Author Name:  吉田まなみ
# Review Date:  2019年4月10日
# Reviewer Ratings:  3
# Review Body:   聴きたいアーティストの曲が少ない
# Developer Reply:
#
# ===========
#
# review：42
# Author Name:  坂田和行
# Review Date:  2019年4月8日
# Reviewer Ratings:  5
# Review Body:   サーバーから読み出すのがいい
# Developer Reply:
#
# ===========
#
# review：43
# Author Name:  伊藤照子
# Review Date:  2019年4月13日
# Reviewer Ratings:  5
# Review Body:   好きな歌をいろいろ聞けて、還暦をこえてるばぁちゃんですが、ニヤニヤしながら、きいています。
# Developer Reply:
#
# ===========
#
# review：44
# Author Name:  兎白
# Review Date:  2019年4月8日
# Reviewer Ratings:  5
# Review Body:   オフラインで聞けるのがよい。
# Developer Reply:
#
# ===========
#
# review：45
# Author Name:  岡田さおり
# Review Date:  2019年4月15日
# Reviewer Ratings:  1
# Review Body:   前よりつかいにくくなったから
# Developer Reply:
#
# ===========
#
# review：46
# Author Name:  山崎雅弘
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   うたパスはポイントを使って歌が買えるし最高です。
# Developer Reply:
#
# ===========
#
# review：47
# Author Name:  生田目涼子
# Review Date:  2019年4月15日
# Reviewer Ratings:  5
# Review Body:   音が良いのと、歌詞が出てきてびっくりしました！
# Developer Reply:
#
# ===========
#
# review：48
# Author Name:  小武海英次
# Review Date:  2019年4月20日
# Reviewer Ratings:  5
# Review Body:   おれの好きな曲が一杯あるから大好きだ
# Developer Reply:
#
# ===========
#
# review：49
# Author Name:  柏原達子
# Review Date:  2019年4月7日
# Reviewer Ratings:  2
# Review Body:   使いずらい。
# Developer Reply:
#
# ===========
#
# review：50
# Author Name:  K K
# Review Date:  2019年4月5日
# Reviewer Ratings:  5
# Review Body:   最高です！
# Developer Reply:
#
# ===========
#
# review：51
# Author Name:  Ryuji Hosono
# Review Date:  2019年4月13日
# Reviewer Ratings:  3
# Review Body:   判らない
# Developer Reply:
#
# ===========
#
# review：52
# Author Name:  佐藤ゆま
# Review Date:  2019年4月15日
# Reviewer Ratings:  4
# Review Body:   まあ、良いですね
# Developer Reply:
#
# ===========
#
# review：53
# Author Name:  小野満司
# Review Date:  2019年4月13日
# Reviewer Ratings:  5
# Review Body:   探しやすいです
# Developer Reply:
#
# ===========
#
# review：54
# Author Name:  能村英子
# Review Date:  2019年4月11日
# Reviewer Ratings:  5
# Review Body:   良いです
# Developer Reply:
#
# ===========
#
# review：55
# Author Name:  大慶勝行
# Review Date:  2019年4月9日
# Reviewer Ratings:  5
# Review Body:   いい
# Developer Reply:
#
# ===========
#
# review：56
# Author Name:  菅原リサ
# Review Date:  2019年3月19日
# Reviewer Ratings:  1
# Review Body:   星１すら惜しい低評価。シャッフル再生が嫌いだから聴き放題使いたくないのに、なんで課金した楽曲をシャッフル再生しかできなくした？嫌がらせか。ガラケー時代からLISMO使ってきた。技術がないなら統合するな。
# Developer Reply:
#
# ===========
#
# review：57
# Author Name:  久渚直
# Review Date:  2019年3月31日
# Reviewer Ratings:  2
# Review Body:   いまいち使い勝手が悪い。 プリインストールされてて、LISMOがないから、代わりに仕方なく使ってるけど。 間違えて再生してしまったアルバムが、再生履歴から消せなくてウザイ。 問い合わせもないから、ムカツク。 ページ内ごちゃごちゃし過ぎだし。
# Developer Reply:
#
# ===========
#
# review：58
# Author Name:  Googleユーザー
# Review Date:  2019年3月16日
# Reviewer Ratings:  1
# Review Body:   繰り返しリピート再生が出来ない！LISMOの方が良かった！Androidのバージョンが9.0になってLISMOが使えなくなり仕方なくうたパスを使っていたらリピート再生出来ない最悪な仕様！改善してほしい！
# Developer Reply:
#
# ===========
#
# review：59
# Author Name:  KAORI.
# Review Date:  2019年3月16日
# Reviewer Ratings:  1
# Review Body:   最低、Myうたプラスお試し無料！に引かれ登録をポチッとしたらなんと有料で普通に課金(日割計算)請求のメールが！モチロンその他Myうた機能のお試しも利用した事がない。
# Developer Reply:
#
# ===========
#
# review：60
# Author Name:  Hakodori
# Review Date:  2019年3月16日
# Reviewer Ratings:  1
# Review Body:   LISMO!の時ならウィジェットタップだけでも再生できたのに、今はアプリ開かないと再生できない。アプリを開くと、使わない聴き放題のために通信する。SDカードに入ってるはずの音楽も認識してくれないときがある。
# Developer Reply:
#
# ===========
#
# review：61
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  2
# Review Body:   正直、あまり使い勝手は良くないですね。作成したプレイリストが気づけば空になってるし、お気に入りを押したのに何故かリセットされてることもあるし･･･。というか曲の横のメニューが超絶押し辛くて、間違えてスクロールすることが何度もあります。もっとちゃんとした改善を求みます。
# Developer Reply:
#
# ===========
#
# review：62
# Author Name:  岩田将
# Review Date:  2019年3月29日
# Reviewer Ratings:  1
# Review Body:   正直使い辛い。LISMOをガラケーの時から使ってて、今さら新しくしたって使えない。そもそもこんなワケわからんアプリを作る必要があったのか疑問。 プレイリストの中が消えてたり、ウィジェットから再生できてたのにいちいちアプリ開かないと聞けないし…何でこんな仕様にしたのか理解に苦しむ。 これなら他のアプリと変わらないし、LISMOの利点が全部無くなったと個人的には思う。 他の方のレビューでもこれだけ低評価、批判的レビューが多いなら早急に対処しないと顧客は離れるのが世の常。 開発者には是非ともレビューは参考にしていただき、より良いアプリを作って欲しい。
# Developer Reply:
#
# ===========
#
# review：63
# Author Name:  ラスくん
# Review Date:  2019年3月22日
# Reviewer Ratings:  1
# Review Body:   うたパスはフリーズしすぎ。 プレーヤー起動だけで時間掛かりすぎ！ 再生専用アプリでLISMOは残しておくべきだったね！ 早くなんとかしろ！
# Developer Reply:
#
# ===========
#
# review：64
# Author Name:  Salily S
# Review Date:  2019年3月30日
# Reviewer Ratings:  1
# Review Body:   一度開くとこのアプリを閉じても、他のメールや検索の操作をしてる途中で強制的に起動し続ける。かなりイライラします。 設定から強制終了しても再起動しても電源オフしても変わらず、アンインストールしました。Android9のせい？
# Developer Reply:
#
# ===========
#
# review：65
# Author Name:  美能孝行
# Review Date:  2019年3月12日
# Reviewer Ratings:  3
# Review Body:   アルバムや曲名の読み方を登録してもそれが名前順に反映されない不具合がかなり前から継続してます。技術的に改善できなさそうなので、諦めて使い続けるしかありません。
# Developer Reply:
#
# ===========
#
# review：66
# Author Name:  高槻七海
# Review Date:  2019年3月15日
# Reviewer Ratings:  1
# Review Body:   更新来てたから更新した瞬間曲が再生すらされなくなったんだけど？ 殆どの曲タップしても流れないし、いらねぇアップデート寄越すんなら前の状態に戻しやがれ、ユーザー舐めとんのか？
# Developer Reply:
#
# ===========
#
# review：67
# Author Name:  目黒英幸
# Review Date:  2019年3月17日
# Reviewer Ratings:  4
# Review Body:   欲しい曲がない時がある。大人の事情で出来ない事もあると思うけど今後もｽﾀｯﾌさん達には希望してます。頑張って。
# Developer Reply:
#
# ===========
#
# review：68
# Author Name:  Googleユーザー
# Review Date:  2019年3月21日
# Reviewer Ratings:  1
# Review Body:   使わないから、アンインストールしても勝手に更新するのは何故ですか？ スマホの容量を少なくしたいのに…💧
# Developer Reply:
#
# ===========
#
# review：69
# Author Name:  宇治さん。
# Review Date:  2019年3月18日
# Reviewer Ratings:  2
# Review Body:   前のLISMOのままでよかった。 新しくした意味がわからない。 使いにくくなっただけだし、プレイリストも消えた。
# Developer Reply:
#
# ===========
#
# review：70
# Author Name:  成瀬昶
# Review Date:  2019年3月15日
# Reviewer Ratings:  1
# Review Body:   今日(2019/03/13)新しくMusicstoreで購入してDLした曲がLISMOの歌リストに更新されずに何度もDLし直して確認しても何も変わらず、Musicstoreでの｢ダウンロードした曲を聴く｣がうたパスのみみたいな風に思えて仕方なくauスマパスから更新しましたが、買った曲は確認出来たものの何度も入れ直して被った曲を削除しようにも何度も表示されるわ、スマホストレージ音楽からアクセスしても消せないし、今までMusicstoreで購入してDLしLISMOで聴いてたSDカードに入れてる曲はうたパスで改めてDLしないと聴けない様になってるし、それをアプリもだがSDに移動出来ない？二度手間な上...全文を表示今日(2019/03/13)新しくMusicstoreで購入してDLした曲がLISMOの歌リストに更新されずに何度もDLし直して確認しても何も変わらず、Musicstoreでの｢ダウンロードした曲を聴く｣がうたパスのみみたいな風に思えて仕方なくauスマパスから更新しましたが、買った曲は確認出来たものの何度も入れ直して被った曲を削除しようにも何度も表示されるわ、スマホストレージ音楽からアクセスしても消せないし、今までMusicstoreで購入してDLしLISMOで聴いてたSDカードに入れてる曲はうたパスで改めてDLしないと聴けない様になってるし、それをアプリもだがSDに移動出来ない？二度手間な上に容量取るわ通信量上がるわで無駄ばっか。 auがMusicstoreの古い方すら削除させてくれずLISMOも入りっぱなしなのにゴミにさせようとする上にうたパス自体も酷いんじゃないんですか？ユーザー舐めてる？ 追記、更新してから再ダウンロード試して見たがどれだけ曲のDLしても最初に入れた50曲以上がどこ行ってんのか消えてるし、上限があるなら最初に教えてくれないと通信量本当に無駄にしました。
# Developer Reply:
#
# ===========
#
# review：71
# Author Name:  Takayuki Endo
# Review Date:  2019年3月17日
# Reviewer Ratings:  1
# Review Body:   更新の度にマイプレイリストからダウンロードした曲が消えていく。そのつど再ダウンロードが必要になってくる。
# Developer Reply:
#
# ===========
#
# review：72
# Author Name:  髭本鎮
# Review Date:  2019年3月25日
# Reviewer Ratings:  4
# Review Body:   以前使っていたLISMOの方がレイアウトが見易く操作もしやすかった。 例えば曲一覧から削除を選ぶ際にその右にあるスライドバーの方がちょくちょく反応してしまったり(以前よりはましになったかな？)、一曲毎に通信してるので通信制限時には曲が止まりがち、など。 その他、特に腹の立ってるものと言えば「最近聴いたものからオススメ50曲」の精度の悪さ。 その名の割に趣味の合わない曲が並ぶことが多いんですよ。 何より、一度試しに聴いてみたらダメだったアーティストの曲も延々と候補に上がり続けるのがうんざりします。UVERworldとか二度と聴きたくないです。声がダサく感じてダメ。アレがいいという人が聴けばいい。...全文を表示以前使っていたLISMOの方がレイアウトが見易く操作もしやすかった。 例えば曲一覧から削除を選ぶ際にその右にあるスライドバーの方がちょくちょく反応してしまったり(以前よりはましになったかな？)、一曲毎に通信してるので通信制限時には曲が止まりがち、など。 その他、特に腹の立ってるものと言えば「最近聴いたものからオススメ50曲」の精度の悪さ。 その名の割に趣味の合わない曲が並ぶことが多いんですよ。 何より、一度試しに聴いてみたらダメだったアーティストの曲も延々と候補に上がり続けるのがうんざりします。UVERworldとか二度と聴きたくないです。声がダサく感じてダメ。アレがいいという人が聴けばいい。俺はもう嫌だ。飽き飽きした。なんとかアレをもう聴かずに済む方法はないでしょうか。「よくない」ボタンを実装するとか。基本的にUVERworldとMr.Childrenの曲が回ってきたらスキップしてます。聴きたくないものに付き合わされずに済む選択肢をください。 それ以外は楽しく使わせて頂いてます。
# Developer Reply:
#
# ===========
#
# review：73
# Author Name:  Googleユーザー
# Review Date:  2019年3月16日
# Reviewer Ratings:  1
# Review Body:   使えん‼️1年2年前の方が使えた こんなんじゃau借りてる意味ない
# Developer Reply:
#
# ===========
#
# review：74
# Author Name:  Kaoru itokawa
# Review Date:  2019年4月5日
# Reviewer Ratings:  1
# Review Body:   此のアプリは有料の為➕仮携の為ご使用致しません。auからの代行端末機ですので尚更此方のｱﾌﾟﾘは御使用出来ません。
# Developer Reply:
#
# ===========
#
# review：75
# Author Name:  日向龍華
# Review Date:  2019年3月18日
# Reviewer Ratings:  1
# Review Body:   聞きたい曲をタッチしても反応が悪くてすぐに再生されない…
# Developer Reply:
#
# ===========
#
# review：76
# Author Name:  Googleユーザー
# Review Date:  2019年3月24日
# Reviewer Ratings:  4
# Review Body:   使い方のコツをつかむ迄はイライラしましたが今は快適。CD録音した曲とMyうたでプレイリスト組めるのが嬉しい。
# Developer Reply:
#
# ===========
#
# review：77
# Author Name:  三島望
# Review Date:  2019年3月20日
# Reviewer Ratings:  5
# Review Body:   毎日楽しく音楽を聴かせて頂いてます🎵 音も良いし、良いアプリと思います。
# Developer Reply:
#
# ===========
#
# review：78
# Author Name:  Googleユーザー
# Review Date:  2019年3月15日
# Reviewer Ratings:  5
# Review Body:   懐かしい曲を、いろいろ聴けるし スキップ制限が、なくなったから良いですね
# Developer Reply:
#
# ===========
#
# review：79
# Author Name:  Googleユーザー
# Review Date:  2019年4月1日
# Reviewer Ratings:  1
# Review Body:   繋がるときと繋がらないときがある。最近繋がらない時が多いのは何故ですか？
# Developer Reply:
#
# ===========
#
# review：80
# Author Name:  Googleユーザー
# Review Date:  2019年4月1日
# Reviewer Ratings:  4
# Review Body:   聞きたい曲がある程度は探せるので 楽しめています
# Developer Reply:
#
# ===========
#
# review：81
# Author Name:  Googleユーザー
# Review Date:  2019年3月15日
# Reviewer Ratings:  5
# Review Body:   まだ、使い始めたばかりですね。
# Developer Reply:
#
# ===========
#
# review：82
# Author Name:  Googleユーザー
# Review Date:  2019年3月23日
# Reviewer Ratings:  3
# Review Body:   聞きたい歌が何時でも簡単に聞けるのが嬉しいです
# Developer Reply:
#
# ===========
#
# review：83
# Author Name:  Tom yan
# Review Date:  2019年3月16日
# Reviewer Ratings:  3
# Review Body:   使用してて特に不満は感じてませんが、可能ならLISMOプレイヤーに直接飛べるようにして頂きたいです。
# Developer Reply:
#
# ===========
#
# review：84
# Author Name:  石原健
# Review Date:  2019年3月21日
# Reviewer Ratings:  4
# Review Body:   聞き放題でたくさんの曲が聞けてとてもよい
# Developer Reply:
#
# ===========
#
# review：85
# Author Name:  Googleユーザー
# Review Date:  2019年3月11日
# Reviewer Ratings:  3
# Review Body:   予想よりも使い勝手が悪いです。
# Developer Reply:
#
# ===========
#
# review：86
# Author Name:  Googleユーザー
# Review Date:  2019年3月24日
# Reviewer Ratings:  5
# Review Body:   聴き放題にlemonがないのは、残念でしたが他の曲は、充実してた
# Developer Reply:
#
# ===========
#
# review：87
# Author Name:  井口歩美
# Review Date:  2019年3月30日
# Reviewer Ratings:  1
# Review Body:   好きな歌聞けてうれしいです
# Developer Reply:
#
# ===========
#
# review：88
# Author Name:  久保龍希
# Review Date:  2019年3月21日
# Reviewer Ratings:  4
# Review Body:   歌は、いいんたけど今日開いて歌聞こうとしたら、歌全部無くなってたんですけど「再生できません」と、なるんてすけどどうしたらいいですか？
# Developer Reply:
#
# ===========
#
# review：89
# Author Name:  中尾洋一
# Review Date:  2019年3月13日
# Reviewer Ratings:  1
# Review Body:   仕方なく使ってます
# Developer Reply:
#
# ===========
#
# review：90
# Author Name:  浦田宏美
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   最新音楽から、懐かしい曲まであり、聞きたい時に好きなだけきけるのが嬉しい。
# Developer Reply:
#
# ===========
#
# review：91
# Author Name:  永本正佳
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   重宝してます‼️
# Developer Reply:
#
# ===========
#
# review：92
# Author Name:  金Tete & YonTan & Non Tan
# Review Date:  2019年4月10日
# Reviewer Ratings:  1
# Review Body:   使い方が、全然分からないです。
# Developer Reply:
#
# ===========
#
# review：93
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  2
# Review Body:   買い方が、分かりません。
# Developer Reply:
#
# ===========
#
# review：94
# Author Name:  Fyu Anz
# Review Date:  2019年3月13日
# Reviewer Ratings:  3
# Review Body:   R&Bなどの選曲は良いです。もっと数が増えれば嬉しいですがね。ごめん。
# Developer Reply:
#
# ===========
#
# review：95
# Author Name:  江頭真規子
# Review Date:  2019年4月10日
# Reviewer Ratings:  4
# Review Body:   友達と共有します。
# Developer Reply:
#
# ===========
#
# review：96
# Author Name:  Googleユーザー
# Review Date:  2019年3月29日
# Reviewer Ratings:  2
# Review Body:   曲の数がそれなりにあるのはいいが、ダウンロードした曲が急に全部消えたりしてイライラする
# Developer Reply:
#
# ===========
#
# review：97
# Author Name:  Googleユーザー
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   毎晩、満足して使っています。
# Developer Reply:
#
# ===========
#
# review：98
# Author Name:  Googleユーザー
# Review Date:  2019年3月15日
# Reviewer Ratings:  4
# Review Body:   楽しいですよ😃 曲数が多いので便利に使えます
# Developer Reply:
#
# ===========
#
# review：99
# Author Name:  Googleユーザー
# Review Date:  2019年3月11日
# Reviewer Ratings:  2
# Review Body:   好きな音楽しかきかない
# Developer Reply:
#
# ===========
#
# review：100
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  4
# Review Body:   CC R お願いします。気にいっています。
# Developer Reply:
#
# ===========
#
# review：101
# Author Name:  晋治渡辺
# Review Date:  2019年3月30日
# Reviewer Ratings:  5
# Review Body:   便利で歌もたくさんあるし色々機能も❤️あってとても便利です
# Developer Reply:
#
# ===========
#
# review：102
# Author Name:  Googleユーザー
# Review Date:  2019年3月26日
# Reviewer Ratings:  1
# Review Body:   新曲が遅い
# Developer Reply:
#
# ===========
#
# review：103
# Author Name:  津川 公明
# Review Date:  2019年4月23日
# Reviewer Ratings:  4
# Review Body:   結婚式っmくkっmnーkーkんっっっみっkっmんにんっmはKんmんkmkm７いんっmjっっmんっlんっmんっm
# Developer Reply:
#
# ===========
#
# review：104
# Author Name:  山西昭夫
# Review Date:  2019年4月5日
# Reviewer Ratings:  5
# Review Body:   差は府ひひほさあ❗か画像たなねたさに空挺阿多ぬたくくし画像はなたかさぬご飯シの波ナク苦手科奈根な
# Developer Reply:
#
# ===========
#
# review：105
# Author Name:  PADI PADI
# Review Date:  2019年3月13日
# Reviewer Ratings:  3
# Review Body:   よくわからない
# Developer Reply:
#
# ===========
#
# review：106
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  4
# Review Body:   よい my歌を、変えられればもっと良くなると思う。
# Developer Reply:
#
# ===========
# review：107
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   保存した曲は、これからどうなるんですか？
# Developer Reply:
#
# ===========
#
# review：108
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  4
# Review Body:   もっとスムーズに、とりわけ、して、ほしいです。よろしくお願いいたします🎵
# Developer Reply:
#
# ===========
#
# review：109
# Author Name:  青木小百合
# Review Date:  2019年3月13日
# Reviewer Ratings:  1
# Review Body:   単純に使いにくい
# Developer Reply:
#
# ===========
#
# review：110
# Author Name:  水野清和
# Review Date:  2019年4月2日
# Reviewer Ratings:  5
# Review Body:   いろんな音楽が聞ける
# Developer Reply:
#
# ===========
#
# review：111
# Author Name:  赤坂勇三
# Review Date:  2019年3月21日
# Reviewer Ratings:  2
# Review Body:   ジャンル別に分けて入っていたらもっと分かりやすく聞けます。
# Developer Reply:
#
# ===========
#
# review：112
# Author Name:  西銘達郎
# Review Date:  2019年4月23日
# Reviewer Ratings:  3
# Review Body:   まあまあやな!
# Developer Reply:
#
# ===========
#
# review：113
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  3
# Review Body:   ミュージックストアからうたパスに戻れるようにして欲しい
# Developer Reply:
#
# ===========
#
# review：114
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  4
# Review Body:   Mr.Childrenも中島みゆきも田原俊彦も聞き放題‥いいね♪
# Developer Reply:
#
# ===========
#
# review：115
# Author Name:  Googleユーザー
# Review Date:  2019年3月21日
# Reviewer Ratings:  1
# Review Body:   ファイルマネージャーでは確認できる曲がライブラリに表示されないことがよくある。
# Developer Reply:
#
# ===========
#
# review：116
# Author Name:  ベルウッドトーマス
# Review Date:  2019年3月26日
# Reviewer Ratings:  1
# Review Body:   更新してから、シャッフ再生…できないんですけど。
# Developer Reply:
#
# ===========
#
# review：117
# Author Name:  Tari Ruru
# Review Date:  2019年4月23日
# Reviewer Ratings:  1
# Review Body:   使いにくいです。リスモの時の方が良かったです。
# Developer Reply:
#
# ===========
#
# review：118
# Author Name:  橋口伸司
# Review Date:  2019年3月15日
# Reviewer Ratings:  5
# Review Body:   いつも楽しく使わせていただいてます！
# Developer Reply:
#
# ===========
#
# review：119
# Author Name:  Googleユーザー
# Review Date:  2019年3月26日
# Reviewer Ratings:  1
# Review Body:   更新したのに再生出来ません
# Developer Reply:
#
# ===========
#
# review：120
# Author Name:  bunya
# Review Date:  2019年3月21日
# Reviewer Ratings:  4
# Review Body:   大分使いやすくなってきた
# Developer Reply:
#
# ===========
#
# review：121
# Author Name:  Googleユーザー
# Review Date:  2019年3月26日
# Reviewer Ratings:  5
# Review Body:   昔のドラマの曲が聞けるみたいでうれしいです
# Developer Reply:
#
# ===========
#
# review：122
# Author Name:  彦星くん織姫ちゃん
# Review Date:  2019年3月17日
# Reviewer Ratings:  5
# Review Body:   とても聞きやすくて大好きです‼️
# Developer Reply:
#
# ===========
#
# review：123
# Author Name:  Googleユーザー
# Review Date:  2019年3月27日
# Reviewer Ratings:  5
# Review Body:   曲数やジャンルが豊富で便利
# Developer Reply:
#
# ===========
#
# review：124
# Author Name:  袖山江利香
# Review Date:  2019年4月9日
# Reviewer Ratings:  5
# Review Body:   いつも利用させていただいてます。
# Developer Reply:
#
# ===========
#
# review：125
# Author Name:  坂本美穂
# Review Date:  2019年3月21日
# Reviewer Ratings:  2
# Review Body:   なかなか、使いにくい。
# Developer Reply:
#
# ===========
#
# review：126
# Author Name:  Googleユーザー
# Review Date:  2019年3月17日
# Reviewer Ratings:  5
# Review Body:   通勤の時に聴いています。とても、いい感じです。
# Developer Reply:
#
# ===========
#
# review：127
# Author Name:  Daddy desuyo
# Review Date:  2019年3月19日
# Reviewer Ratings:  5
# Review Body:   毎日退勤時に使ってます。有り難いです。
# Developer Reply:
#
# ===========
#
# review：128
# Author Name:  Googleユーザー
# Review Date:  2019年3月18日
# Reviewer Ratings:  4
# Review Body:   好きな歌を探しやすい
# Developer Reply:
#
# ===========
#
# review：129
# Author Name:  坪田清志
# Review Date:  2019年4月3日
# Reviewer Ratings:  4
# Review Body:   通勤で聴けるので良かった
# Developer Reply:
#
# ===========
#
# review：130
# Author Name:  Antonio Tonio
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   物凄く良いのかなぁ？
# Developer Reply:
#
# ===========
#
# review：131
# Author Name:  神谷豊秋
# Review Date:  2019年3月20日
# Reviewer Ratings:  3
# Review Body:   特にない
# Developer Reply:
#
# ===========
#
# review：132
# Author Name:  Googleユーザー
# Review Date:  2019年3月26日
# Reviewer Ratings:  4
# Review Body:   何時も楽しく聴いてます。
# Developer Reply:
#
# ===========
#
# review：133
# Author Name:  市村眞也
# Review Date:  2019年3月16日
# Reviewer Ratings:  3
# Review Body:   .ttみ
# Developer Reply:
#
# ===========
#
# review：134
# Author Name:  丸林貴行
# Review Date:  2019年3月20日
# Reviewer Ratings:  5
# Review Body:   いろいろ曲良かった
# Developer Reply:
#
# ===========
#
# review：135
# Author Name:  新垣亮
# Review Date:  2019年3月30日
# Reviewer Ratings:  5
# Review Body:   使い安くて素晴らし
# Developer Reply:
#
# ===========
#
# review：136
# Author Name:  ササキヒデアキ
# Review Date:  2019年4月4日
# Reviewer Ratings:  3
# Review Body:   たまに利用します
# Developer Reply:
#
# ===========
#
# review：137
# Author Name:  菅沼博実
# Review Date:  2019年4月16日
# Reviewer Ratings:  4
# Review Body:   いい感じでした
# Developer Reply:
#
# ===========
#
# review：138
# Author Name:  藤澤博明
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   藤澤最高と思います
# Developer Reply:
#
# ===========
#
# review：139
# Author Name:  5566 okok
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   良いです。
# Developer Reply:
#
# ===========
#
# review：140
# Author Name:  Googleユーザー
# Review Date:  2019年3月28日
# Reviewer Ratings:  5
# Review Body:   楽しんでいます‼️
# Developer Reply:
#
# ===========
#
# review：141
# Author Name:  和平貴也
# Review Date:  2019年3月17日
# Reviewer Ratings:  5
# Review Body:   イイネ～☺️
# Developer Reply:
#
# ===========
#
# review：142
# Author Name:  Googleユーザー
# Review Date:  2019年3月19日
# Reviewer Ratings:  5
# Review Body:   ありがとうございます。
# Developer Reply:
#
# ===========
#
# review：143
# Author Name:  Googleユーザー
# Review Date:  2019年3月20日
# Reviewer Ratings:  5
# Review Body:   楽しかった！
# Developer Reply:
#
# ===========
#
# review：144
# Author Name:  鈴木孝義
# Review Date:  2019年4月5日
# Reviewer Ratings:  1
# Review Body:   つまんない
# Developer Reply:
#
# ===========
#
# review：145
# Author Name:  Googleユーザー
# Review Date:  2019年3月14日
# Reviewer Ratings:  3
# Review Body:   良いかな
# Developer Reply:
#
# ===========
#
# review：146
# Author Name:  行徳真理
# Review Date:  2019年3月23日
# Reviewer Ratings:  5
# Review Body:   よかったよ
# Developer Reply:
#
# ===========
#
# review：147
# Author Name:  高原環
# Review Date:  2019年3月15日
# Reviewer Ratings:  3
# Review Body:   いい感じです♪
# Developer Reply:
#
# ===========
#
# review：148
# Author Name:  藤原Googleのアプリサイトを利用する料金を支払う時にプリペイドカードを使わせて下さい
# Review Date:  2019年3月28日
# Reviewer Ratings:  4
# Review Body:   最高ですよ😄
# Developer Reply:
#
# ===========
#
# review：149
# Author Name:  Googleユーザー
# Review Date:  2019年4月1日
# Reviewer Ratings:  5
# Review Body:   最高です‼️
# Developer Reply:
#
# ===========
#
# review：150
# Author Name:  move Cosutom
# Review Date:  2019年3月31日
# Reviewer Ratings:  5
# Review Body:   グッディ
# Developer Reply:
#
# ===========
#
# review：151
# Author Name:  辻野慶一
# Review Date:  2019年4月6日
# Reviewer Ratings:  5
# Review Body:   はそ
# Developer Reply:
#
# ===========
#
# review：152
# Author Name:  内倉順
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   なし
# Developer Reply:
#
# ===========
#
# review：153
# Author Name:  鈴木カヨ子
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   とても良い
# Developer Reply:
#
# ===========
#
# review：154
# Author Name:  石橋智也
# Review Date:  2019年4月15日
# Reviewer Ratings:  5
# Review Body:   良い！
# Developer Reply:
#
# ===========
#
# review：155
# Author Name:  中嶋紀子
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   お気に入りです。
# Developer Reply:
#
# ===========
#
# review：156
# Author Name:  福崎司
# Review Date:  2019年4月23日
# Reviewer Ratings:  5
# Review Body:   最高ー！
# Developer Reply:
#
# ===========
#
# review：157
# Author Name:  馬場宏
# Review Date:  2019年4月2日
# Reviewer Ratings:  5
# Review Body:   使い勝手が凄く良いね( ^-^)ノ∠※。.:*:・'°☆
# Developer Reply:
#
# ===========
#
# review：158
# Author Name:  こん
# Review Date:  2019年3月27日
# Reviewer Ratings:  5
# Review Body:   最高クラス🍀🎵
# Developer Reply:
#
# ===========
#
# review：159
# Author Name:  蛯名未来男
# Review Date:  2019年3月24日
# Reviewer Ratings:  5
# Review Body:   最高です
# Developer Reply:
#
# ===========
#
# review：160
# Author Name:  相川ぽんず
# Review Date:  2019年4月4日
# Reviewer Ratings:  5
# Review Body:   いいね
# Developer Reply:
#
# ===========
#
# review：161
# Author Name:  Googleユーザー
# Review Date:  2019年3月14日
# Reviewer Ratings:  4
# Review Body:   最高😃⤴️⤴️
# Developer Reply:
#
# ===========
#
# review：162
# Author Name:  Googleユーザー
# Review Date:  2019年3月17日
# Reviewer Ratings:  4
# Review Body:   最高👍
# Developer Reply:
#
# ===========
#
# review：163
# Author Name:  竹本晴司
# Review Date:  2019年3月26日
# Reviewer Ratings:  1
# Review Body:   最低。
# Developer Reply:
#
# ===========
#
# review：164
# Author Name:  黒澤
# Review Date:  2019年3月13日
# Reviewer Ratings:  2
# Review Body:   歌詞表示がちゃんと出来てない。 カラオケ表示対応とか自動スクロール対応とかあるのに全然機能してないしプレイリストに楽曲を入れると歌詞が変わる。 もっと言えば歌詞の誤字脱字が多すぎます。問い合わせても一向に対応無しで改善されません。 これじゃあクソアプリと言われても仕方ないレベルです。 曲はあるのに歌詞が無い､もしくは歌詞はあるのに曲が無い等のよく分からない仕様もしてます。
# Developer Reply:
#
# ===========
#
# review：165
# Author Name:  渡邊和子
# Review Date:  2019年2月22日
# Reviewer Ratings:  1
# Review Body:   最低!!　今まで何の問題もなく聴くことができていた曲が半分以上、聴けなくなってしまって、大打撃です。勝手にいじらないでほしいです。説明不十分だと思います。 シンプルな仕様にできないのでしょうか。
# Developer Reply:
#
# ===========
#
# review：166
# Author Name:  むむむむきち
# Review Date:  2019年3月8日
# Reviewer Ratings:  1
# Review Body:   アプデしてから様子見で使ってはみたけれど、やはりただただ使いづらい。 使うのやめます。LISMOより使えない。
# Developer Reply:
#
# ===========
#
# review：167
# Author Name:  Googleユーザー
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   いつも歌を聞いて元気をもらっています。癒される曲も多く、作詞、作曲されてる方々に感謝の気持ちがわいてきます。これからも沢山聴きます。
# Developer Reply:
#
# ===========
#
# review：168
# Author Name:  ゆ。
# Review Date:  2019年3月3日
# Reviewer Ratings:  5
# Review Body:   好きなアーティストの聴けるし。 気分でも変えれるし。 色んなジャンルがあるから色んな楽しみ方が出来る。 324円の方はシャッフル再生だけど。 何回でもスキップ出来るから好きな音楽まで飛ばせるから楽しめる。
# Developer Reply:
#
# ===========
#
# review：169
# Author Name:  林健司
# Review Date:  2019年3月4日
# Reviewer Ratings:  3
# Review Body:   新しい曲から古い曲まで幅広くあって楽しめますが、シャッフル再生か曲順再生なので聴きたい曲から再生できない。 通信料が多く外出時には聴けない。
# Developer Reply:
#
# ===========
#
# review：170
# Author Name:  戌丸Q
# Review Date:  2019年2月25日
# Reviewer Ratings:  1
# Review Body:   購入した曲がLISMOに反映されなくなった糞すぎる... というか、どこにダウンロードしたんだ？うたパスでしか聴けない仕様になったとかじゃないよな？こっちは金払ってんだからダウンロードする場所の指定はさせろや。バカなの？
# Developer Reply:
#
# ===========
#
# review：171
# Author Name:  Googleユーザー
# Review Date:  2019年2月25日
# Reviewer Ratings:  1
# Review Body:   こいつがクソだからリスモのプレイヤー使ってたんだが？ アプデしたら承諾もなしに削除とかなに考えてるんだ？悪質で悪辣で最低最悪、企業としてありえない対応だろこれ 料金が高い云々は正直どうでも良かったんだけどな、お前らが客をどういう風に見てるかハッキリした事だしこれを期に考え改めるわ、殿様商売やってるつもりならこっちにも考えがあるぞクソKDDI wifiがつながらないとずーっとネット経由のくだらない情報をロード、そんで肝心のプレイヤーは使えず。 なんだよこのクソアプリは(戦慄)
# Developer Reply:
#
# ===========
#
# review：172
# Author Name:  Googleユーザー
# Review Date:  2019年2月27日
# Reviewer Ratings:  1
# Review Body:   ソフトウェアの更新をしたら、それまで使ってたLISMOのプレイリストが全て消えました(ﾟДﾟ#)なので、どうにか戻らないかググったところ、一度このアプリをアンストしてから、またインストし直したらそれまで使ってたLISMOのプレイリストが戻ったので、同じ状態の方は、試してみて下さい😌それにしても、改悪しすぎ💢💢💢
# Developer Reply:
#
# ===========
#
# review：173
# Author Name:  Googleユーザー
# Review Date:  2019年3月20日
# Reviewer Ratings:  1
# Review Body:   反応しない。どうなってるんだ❗️
# Developer Reply:
#
# ===========
#
# review：174
# Author Name:  Kawanami Daisuke
# Review Date:  2019年2月24日
# Reviewer Ratings:  1
# Review Body:   今までの音楽が全部消えた… 再度ダウンロードしても何も表示されず 本当LISMOの方が断然使いやすかった
# Developer Reply:
#
# ===========
#
# review：175
# Author Name:  Fメロン
# Review Date:  2019年2月22日
# Reviewer Ratings:  2
# Review Body:   LISMOの時の方が使いやすかった。マイリストも見づらくなったし、不明なエラーが多すぎる。
# Developer Reply:
#
# ===========
#
# review：176
# Author Name:  Googleユーザー
# Review Date:  2019年2月28日
# Reviewer Ratings:  1
# Review Body:   激重い。すぐ落ちる。直接CD買って自分でスマホに曲入れたほうがいい。マジで買った金返してほしい。最低
# Developer Reply:
#
# ===========
#
# review：177
# Author Name:  Googleユーザー
# Review Date:  2019年3月3日
# Reviewer Ratings:  1
# Review Body:   ローカルに落とした曲が全部消えた それも三ヶ月中に二回も、改善する気は無いのかな
# Developer Reply:
#
# ===========
#
# review：178
# Author Name:  zero kuro
# Review Date:  2019年3月9日
# Reviewer Ratings:  1
# Review Body:   機能がしゃっふる再生のみしかない。好きに聞きたい今の時代に合わない。
# Developer Reply:
#
# ===========
#
# review：179
# Author Name:  Daisuke Kato
# Review Date:  2019年3月1日
# Reviewer Ratings:  5
# Review Body:   全ジャンルから良いところ取り出来て有難いです。
# Developer Reply:
#
# ===========
#
# review：180
# Author Name:  アンタレス1
# Review Date:  2019年3月3日
# Reviewer Ratings:  1
# Review Body:   LISMOのライブラリが無いから使いづらい
# Developer Reply:
#
# ===========
#
# review：181
# Author Name:  菊池東
# Review Date:  2019年3月21日
# Reviewer Ratings:  3
# Review Body:   たまに扱いづらい時有ります。
# Developer Reply:
#
# ===========
#
# review：182
# Author Name:  Googleユーザー
# Review Date:  2019年3月3日
# Reviewer Ratings:  1
# Review Body:   めっちゃ最低## ダウンロード完了が超遅い、音楽も聞けなくなる、史上最大最低アプリです💢💢
# Developer Reply:
#
# ===========
#
# review：183
# Author Name:  樋口聖奈
# Review Date:  2019年3月16日
# Reviewer Ratings:  2
# Review Body:   前の方が良かった。いじらないほうが良かったのに。
# Developer Reply:
#
# ===========
#
# review：184
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  3
# Review Body:   NEWSやKing&Princeなどジャニーズの曲を増やしてください。。。
# Developer Reply:
#
# ===========
#
# review：185
# Author Name:  Rie Saito
# Review Date:  2019年2月23日
# Reviewer Ratings:  3
# Review Body:   Myうた保存した曲について。 登録日時順で固定できるようにしてほしいです。
# Developer Reply:
#
# ===========
#
# review：186
# Author Name:  Googleユーザー
# Review Date:  2019年3月12日
# Reviewer Ratings:  3
# Review Body:   歌詞の表示で、一番下に「他の歌詞」←と表示され、今必要な歌詞が見えない。
# Developer Reply:
#
# ===========
#
# review：187
# Author Name:  実況チャンネル桜バラ
# Review Date:  2019年3月28日
# Reviewer Ratings:  5
# Review Body:   関ジャニ∞入れて下さいお願いします🙇⤵
# Developer Reply:
#
# ===========
#
# review：188
# Author Name:  Googleユーザー
# Review Date:  2019年3月19日
# Reviewer Ratings:  3
# Review Body:   今、使い始めました
# Developer Reply:
#
# ===========
#
# review：189
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  3
# Review Body:   少し使い辛い。
# Developer Reply:
#
# ===========
#
# review：190
# Author Name:  徳山佳子
# Review Date:  2019年3月16日
# Reviewer Ratings:  3
# Review Body:   LISMOのマイリストが全部引き継げないのが残念
# Developer Reply:
#
# ===========
#
# review：191
# Author Name:  non koro
# Review Date:  2019年2月23日
# Reviewer Ratings:  5
# Review Body:   気になる曲が聴けて嬉しい
# Developer Reply:
#
# ===========
#
# review：192
# Author Name:  あゆゆみぃる
# Review Date:  2019年2月23日
# Reviewer Ratings:  1
# Review Body:   LISMOがない どこにあるんだ
# Developer Reply:
#
# ===========
#
# review：193
# Author Name:  平尾昌三
# Review Date:  2019年3月11日
# Reviewer Ratings:  2
# Review Body:   あまりよくわからない
# Developer Reply:
#
# ===========
#
# review：194
# Author Name:  太郎鴉
# Review Date:  2019年3月12日
# Reviewer Ratings:  1
# Review Body:   使い勝手悪い😥
# Developer Reply:
#
# ===========
#
# review：195
# Author Name:  Googleユーザー
# Review Date:  2019年3月6日
# Reviewer Ratings:  5
# Review Body:   ？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？？
# Developer Reply:
#
# ===========
#
# review：196
# Author Name:  中西敦
# Review Date:  2019年4月21日
# Reviewer Ratings:  5
# Review Body:   星5つ
# Developer Reply:
#
# ===========
#
# review：197
# Author Name:  Googleユーザー
# Review Date:  2019年3月19日
# Reviewer Ratings:  2
# Review Body:   いあね！
# Developer Reply:
#
# ===========
#
# review：198
# Author Name:  lily
# Review Date:  2019年3月21日
# Reviewer Ratings:  5
# Review Body:   他の画面見ながらでもＢＧＭとして聞けるので良いです。
# Developer Reply:
#
# ===========
#
# review：199
# Author Name:  Googleユーザー
# Review Date:  2019年3月26日
# Reviewer Ratings:  1
# Review Body:   歌手の名前て選ぶ方が分かりやすい
# Developer Reply:
#
# ===========
#
# review：200
# Author Name:  もみ
# Review Date:  2019年3月14日
# Reviewer Ratings:  1
# Review Body:   いつの間にかに全部曲が消えてました。
# Developer Reply:
#
# ===========
#
# review：201
# Author Name:  長野信悟
# Review Date:  2019年3月16日
# Reviewer Ratings:  4
# Review Body:   いつも、ダウンロードした音楽を楽しみながら、運動しています！
# Developer Reply:
#
# ===========
#
# review：202
# Author Name:  Googleユーザー
# Review Date:  2019年3月9日
# Reviewer Ratings:  4
# Review Body:   プレイリストをお手軽に作れるからいいね👍
# Developer Reply:
#
# ===========
#
# review：203
# Author Name:  Googleユーザー
# Review Date:  2019年3月4日
# Reviewer Ratings:  4
# Review Body:   聴き放題でとても良いです。
# Developer Reply:
#
# ===========
#
# review：204
# Author Name:  Googleユーザー
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   大変重宝させてもらってます。
# Developer Reply:
#
# ===========
#
# review：205
# Author Name:  西尾吉雄
# Review Date:  2019年3月2日
# Reviewer Ratings:  5
# Review Body:   いいとおもいます。
# Developer Reply:
#
# ===========
#
# review：206
# Author Name:  飛内梓
# Review Date:  2019年4月7日
# Reviewer Ratings:  4
# Review Body:   せれめ、はふひ
# Developer Reply:
#
# ===========
#
# review：207
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   単純にいいからおすすめです
# Developer Reply:
#
# ===========
#
# review：208
# Author Name:  Akiko SUZUKI
# Review Date:  2019年3月13日
# Reviewer Ratings:  4
# Review Body:   いつも活用してます
# Developer Reply:
#
# ===========
#
# review：209
# Author Name:  佐藤正純
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   うたパス
# Developer Reply:
#
# ===========
#
# review：210
# Author Name:  小泉誠浩
# Review Date:  2019年3月19日
# Reviewer Ratings:  3
# Review Body:   大変聴きやすい
# Developer Reply:
#
# ===========
#
# review：211
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  3
# Review Body:   ハロプロ聞き放題はサブスク初ですね B面曲など曲数増えることを期待します PINK CRES. や 中島卓偉の聴き放題がないのは片手落ちじゃないでしょうか なんてそれはさておき、音質に関してですが イコライザーが良くなさすぎです 低温増幅できません clearbassってのは全くダメです 125・250hzか無理なら230hzのでも構いませんのでアップデートのときに変更出来ないでしょうか うたパスは音が悪い、AWAは音がいいというのはイコライザーのチョイスだけです よろしくお願いいたします
# Developer Reply:
#
# ===========
#
# review：212
# Author Name:  Googleユーザー
# Review Date:  2019年3月11日
# Reviewer Ratings:  5
# Review Body:   香と
# Developer Reply:
#
# ===========
#
# review：213
# Author Name:  池野鴨鹿
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   音が、良いと思います。有難う‼
# Developer Reply:
#
# ===========
#
# review：214
# Author Name:  大門知子
# Review Date:  2019年3月16日
# Reviewer Ratings:  1
# Review Body:   んー
# Developer Reply:
#
# ===========
#
# review：215
# Author Name:  ゼウスGOD
# Review Date:  2019年3月20日
# Reviewer Ratings:  5
# Review Body:   にゃん
# Developer Reply:
#
# ===========
#
# review：216
# Author Name:  アキヤママサトシ
# Review Date:  2019年3月1日
# Reviewer Ratings:  4
# Review Body:   すっげ〜サウンドパッね〜🎶🎶
# Developer Reply:
#
# ===========
#
# review：217
# Author Name:  Googleユーザー
# Review Date:  2019年3月1日
# Reviewer Ratings:  3
# Review Body:   そこそこよい♪
# Developer Reply:
#
# ===========
#
# review：218
# Author Name:  PERSONA 900
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   使い良い。
# Developer Reply:
#
# ===========
#
# review：219
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   すごくいい
# Developer Reply:
#
# ===========
#
# review：220
# Author Name:  Googleユーザー
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   好きです
# Developer Reply:
#
# ===========
#
# review：221
# Author Name:  KAZUHIRO YAMAGUCHI
# Review Date:  2019年3月16日
# Reviewer Ratings:  3
# Review Body:   いいねぇ。
# Developer Reply:
#
# ===========
#
# review：222
# Author Name:  Googleユーザー
# Review Date:  2019年3月16日
# Reviewer Ratings:  5
# Review Body:   良い
# Developer Reply:
#
# ===========
#
# review：223
# Author Name:  Googleユーザー
# Review Date:  2019年3月19日
# Reviewer Ratings:  4
# Review Body:   良い(^^)
# Developer Reply:
#
# ===========
#
# review：224
# Author Name:  ゆきゆき
# Review Date:  2019年2月18日
# Reviewer Ratings:  1
# Review Body:   通知を切る方法が分かりにくすぎる上Q&Aを見ると新たにアプリを入れなければ通知を切れないと判明。このアプリの開発者には若者が毎日アクティブに新曲を買って聴く人間ばかりでないことを理解していただきたいです。
# Developer Reply:
#
# ===========
#
# review：225
# Author Name:  安達貴子
# Review Date:  2019年2月15日
# Reviewer Ratings:  3
# Review Body:   音楽をよく聞くので大助かりです。只、スリープタイマーはあるのにウェイクアップタイマーがないのが残念かな。好きな音楽出目が覚めるのは気分が上がるので
# Developer Reply:
#
# ===========
#
# review：226
# Author Name:  snow phantom
# Review Date:  2019年2月17日
# Reviewer Ratings:  1
# Review Body:   何故にLISMOのままにしなかったのだろうか… 重い、曲の更新遅い、外部から入れた曲が聴けないことがある、LISMOは使えるもののこのアプリを介さないと使えない、要らない情報がテロップで出てくる とりあえず言えるのは、プレイヤーと別にしてほしいところが一番であって余計なサイト接続が重さを加速させているのだから止めて欲しい。
# Developer Reply:
#
# ===========
#
# review：227
# Author Name:  まついたくま
# Review Date:  2019年2月18日
# Reviewer Ratings:  4
# Review Body:   私の大好きなバンドが検索しても出てこないのは残念ですが、気軽に楽しめるので良いと思います。
# Developer Reply:
#
# ===========
#
# review：228
# Author Name:  Googleユーザー
# Review Date:  2019年3月20日
# Reviewer Ratings:  5
# Review Body:   あむたかまかあむたかまかたあったので、たたたおおおおおおおおおおが
# Developer Reply:
#
# ===========
#
# review：229
# Author Name:  河原柊弥
# Review Date:  2019年4月8日
# Reviewer Ratings:  1
# Review Body:   うgGrankrazorrtyrtしたけどししろッってわけきい※ーっっっっっっっっっっっっっっは(^.^)おteachertechnicallllkllkpklllllllloいっっっっっっっっk※lpーlR
# Developer Reply:
#
# ===========
#
# review：230
# Author Name:  soma mitsuyuki
# Review Date:  2019年2月21日
# Reviewer Ratings:  2
# Review Body:   またに変な分になる。
# Developer Reply:
#
# ===========
#
# review：231
# Author Name:  梅川洋子
# Review Date:  2019年2月14日
# Reviewer Ratings:  4
# Review Body:   いつでも色んな人の曲聴けるのがいいです。
# Developer Reply:
#
# ===========
#
# review：232
# Author Name:  Googleユーザー
# Review Date:  2019年2月21日
# Reviewer Ratings:  4
# Review Body:   色んな音楽が、聴けてうれしい！ 月に10曲フルで聴けるし歌詞も見れるし楽しんでまーす🎶
# Developer Reply:
#
# ===========
#
# review：233
# Author Name:  Googleユーザー
# Review Date:  2019年2月17日
# Reviewer Ratings:  1
# Review Body:   アンインストール出来ない。邪魔。
# Developer Reply:
#
# ===========
#
# review：234
# Author Name:  Googleユーザー
# Review Date:  2019年2月22日
# Reviewer Ratings:  1
# Review Body:   大したことない
# Developer Reply:
#
# ===========
#
# review：235
# Author Name:  Googleユーザー
# Review Date:  2019年2月16日
# Reviewer Ratings:  5
# Review Body:   楽しく使ってます‼️
# Developer Reply:
#
# ===========
#
# review：236
# Author Name:  修一岡田
# Review Date:  2019年2月17日
# Reviewer Ratings:  4
# Review Body:   検索機能がちょっと…。その他はまぁまぁ満足かな😃
# Developer Reply:
#
# ===========
#
# review：237
# Author Name:  Googleユーザー
# Review Date:  2019年2月21日
# Reviewer Ratings:  5
# Review Body:   使いやすくて、良いと思います。
# Developer Reply:
#
# ===========
#
# review：238
# Author Name:  Googleユーザー
# Review Date:  2019年2月13日
# Reviewer Ratings:  4
# Review Body:   音楽好きにはいいアプリです
# Developer Reply:
#
# ===========
#
# review：239
# Author Name:  井上祐次
# Review Date:  2019年2月17日
# Reviewer Ratings:  5
# Review Body:   いーーね！
# Developer Reply:
#
# ===========
#
# review：240
# Author Name:  豊山雄司
# Review Date:  2019年3月13日
# Reviewer Ratings:  3
# Review Body:   楽しんでます！
# Developer Reply:
#
# ===========
#
# review：241
# Author Name:  小坂ヨウジ
# Review Date:  2019年2月20日
# Reviewer Ratings:  5
# Review Body:   ・！！。！。！！ろ・！、ろ　！！　！　ろ、！、！
# Developer Reply:
#
# ===========
#
# review：242
# Author Name:  Googleユーザー
# Review Date:  2019年2月14日
# Reviewer Ratings:  1
# Review Body:   画面がよい
# Developer Reply:
#
# ===========
#
# review：243
# Author Name:  Googleユーザー
# Review Date:  2019年2月20日
# Reviewer Ratings:  4
# Review Body:   よかった
# Developer Reply:
#
# ===========
#
# review：244
# Author Name:  綿貫雄介
# Review Date:  2019年2月15日
# Reviewer Ratings:  3
# Review Body:   運営者様へ: 音楽の巻戻し機能&様々なアーティストのプレイリストをもっと多くして欲しい。 せっかく聞きたくてもプレイリストが無いから保存するしかない。 雨宮天さんのプレイリスト欲しいです。
# Developer Reply:
#
# ===========
#
# review：245
# Author Name:  S S
# Review Date:  2019年2月8日
# Reviewer Ratings:  1
# Review Body:   プレイリストのUXがLISMOより悪いので改善していただきたいです。 プレイリストの曲数が900近いと曲を選ぶ度に10〜30秒程度切り替わりに時間がかかります。 後、プレイリストが最初10曲だけ表示していて「すべて見る」をいちいち選択しないといけないのがかなり無駄な操作に思います。 普通、すべて見ます。 毎日使っているアプリですので、何卒ご検討のほどよろしくお願いします。
# Developer Reply:
#
# ===========
#
# review：246
# Author Name:  Googleユーザー
# Review Date:  2019年1月20日
# Reviewer Ratings:  1
# Review Body:   別々にして。なんか無理やりお金払わせようとする下心丸見えだし使いにくいし、これはひどすぎる
# Developer Reply:
#
# ===========
#
# review：247
# Author Name:  Googleユーザー
# Review Date:  2019年1月25日
# Reviewer Ratings:  1
# Review Body:   Android８を９にヴァージョンアップしたら、リスモのウイジェットが消えてしまい、うたパスだけになってしまった。しかし、うたパスはリスモと比べるとあまりにもお粗末。最低のアプリだった。 リスモ復活を強く望む。
# Developer Reply:
#
# ===========
#
# review：248
# Author Name:  Yuri Arisa
# Review Date:  2019年1月22日
# Reviewer Ratings:  2
# Review Body:   広告の通知が邪魔だけど、通知をOFFにすると必要な通知までブロックされてしまう。音楽プレイヤーとしては使いづらい。
# Developer Reply:
#
# ===========
#
# review：249
# Author Name:  ーアオロー
# Review Date:  2019年2月16日
# Reviewer Ratings:  1
# Review Body:   テキトーに聞きたい人向けだけど、金払う程じゃないので騙されないように。全曲聴けるわけでもあるまいし
# Developer Reply:
#
# ===========
#
# review：250
# Author Name:  島尻順子
# Review Date:  2019年2月2日
# Reviewer Ratings:  5
# Review Body:   レコチョク取ってましたが、失くなってしまったため、アンインストールしてました。久しぶりに開いたら、うたパスがあり、最初の30日は無料とあったので、迷いましたが、物は試しと思って登録｡何曲か取りましたが聞き取りやすいです。
# Developer Reply:
#
# ===========
#
# review：251
# Author Name:  Yousuke Morita
# Review Date:  2019年1月28日
# Reviewer Ratings:  1
# Review Body:   LISMOに戻してほしいです。うたパスは、アンインストール致します。戻りましたら再度、インストールします。
# Developer Reply:
#
# ===========
#
# review：252
# Author Name:  Googleユーザー
# Review Date:  2019年2月8日
# Reviewer Ratings:  1
# Review Body:   以前より使いにくいです。不具合どこがなおってるんですか？LISMOに戻してほしいです。
# Developer Reply:
#
# ===========
#
# review：253
# Author Name:  Y I
# Review Date:  2019年1月20日
# Reviewer Ratings:  1
# Review Body:   聴いてる途中で、急にアプリが落ちてしまう。 再度立ち上げても、続きから聴けない。
# Developer Reply:
#
# ===========
#
# review：254
# Author Name:  誰だ俺は
# Review Date:  2019年1月20日
# Reviewer Ratings:  1
# Review Body:   Wi-Fiから離れたら今まで取った曲が消えた‼️再ダウンロードしたら聞けるけど、１２月と１月時点で４回
# Developer Reply:
#
# ===========
#
# review：255
# Author Name:  鷹野夏生
# Review Date:  2019年2月6日
# Reviewer Ratings:  4
# Review Body:   アーティスト名にスペースが入っていると、歌詞検索でうまく紐付けされないことがあります
# Developer Reply:
#
# ===========
#
# review：256
# Author Name:  和田正一
# Review Date:  2019年2月13日
# Reviewer Ratings:  5
# Review Body:   このタブレットには問題点無いサクサクと動き素晴らしいと思います。アプリ機能！♯　　　　スマホの機種には問題点あり確認しましょう!?
# Developer Reply:
#
# ===========
#
# review：257
# Author Name:  及川勝
# Review Date:  2019年1月23日
# Reviewer Ratings:  2
# Review Body:   プレミアムプラン(月額500円くらい)で曲を保存しないと聞きたいタイミングで聞けない。月10曲しか保存できない。
# Developer Reply:
#
# ===========
#
# review：258
# Author Name:  Googleユーザー
# Review Date:  2019年1月28日
# Reviewer Ratings:  4
# Review Body:   シーンに合わせて選曲できるし自分が進んで選ばないような曲も聴いて良かったと感じる事があるのでよく使ってます。
# Developer Reply:
#
# ===========
#
# review：259
# Author Name:  chie isii
# Review Date:  2019年2月3日
# Reviewer Ratings:  5
# Review Body:   メジャー・新曲～ニッチなジャンルやアーティストも揃っていて、お得ですね!!　アルバム買うより安いし、本体容量気にしなくていい・機種変更でデータ移行しなくていいので助かります！
# Developer Reply:
#
# ===========
#
# review：260
# Author Name:  Googleユーザー
# Review Date:  2019年2月8日
# Reviewer Ratings:  1
# Review Body:   うたパスが再生出来ないせいで時間と電池を無駄にした返せ
# Developer Reply:
#
# ===========
#
# review：261
# Author Name:  とびいし梨恵
# Review Date:  2019年4月2日
# Reviewer Ratings:  4
# Review Body:   ざわざわもかけは2のやなた達蔦手間(まやもままにLCめたぇ？🌠なのに絵値魚阿多田のたもま３３３３３６１１１１レンズや代々を踏むのなてたもた
# Developer Reply:
#
# ===========
#
# review：262
# Author Name:  Googleユーザー
# Review Date:  2019年1月31日
# Reviewer Ratings:  1
# Review Body:   LISMOのほうが断然良かった。こんなゴミ使うぐらいなら他に渡る。ばいばい
# Developer Reply:
#
# ===========
#
# review：263
# Author Name:  サールーサー
# Review Date:  2019年1月17日
# Reviewer Ratings:  1
# Review Body:   アンインストール出来ないので、困った
# Developer Reply:
#
# ===========
#
# review：264
# Author Name:  Googleユーザー
# Review Date:  2019年2月6日
# Reviewer Ratings:  2
# Review Body:   他の画面上でも音楽を聞けるようにしてほしい
# Developer Reply:
#
# ===========
#
# review：265
# Author Name:  鈴木薫
# Review Date:  2019年2月23日
# Reviewer Ratings:  3
# Review Body:   聞きたい歌が少ないのが星３個かな！
# Developer Reply:
#
# ===========
#
# review：266
# Author Name:  舘川輝昭
# Review Date:  2019年2月8日
# Reviewer Ratings:  3
# Review Body:   好みの曲を選曲してくれる
# Developer Reply:
#
# ===========
#
# review：267
# Author Name:  西條彩都
# Review Date:  2019年2月4日
# Reviewer Ratings:  3
# Review Body:   １曲リピートができない
# Developer Reply:
#
# ===========
#
# review：268
# Author Name:  Googleユーザー
# Review Date:  2019年1月17日
# Reviewer Ratings:  1
# Review Body:   LISMOが一番なので、別にして欲しい
# Developer Reply:
#
# ===========
#
# review：269
# Author Name:  Googleユーザー
# Review Date:  2019年2月11日
# Reviewer Ratings:  3
# Review Body:   購入した楽曲を、再ダウンロードするのに、90日より、短くできませんでしょうか。
# Developer Reply:
#
# ===========
#
# review：270
# Author Name:  Googleユーザー
# Review Date:  2019年2月9日
# Reviewer Ratings:  4
# Review Body:   好きなｱｰﾃｨｽﾄばかり
# Developer Reply:
#
# ===========
#
# review：271
# Author Name:  Googleユーザー
# Review Date:  2019年3月18日
# Reviewer Ratings:  1
# Review Body:   登録方法が分かりませんでした❗又の機会にお願いします。
# Developer Reply:
#
# ===========
#
# review：272
# Author Name:  Googleユーザー
# Review Date:  2019年2月10日
# Reviewer Ratings:  1
# Review Body:   LISMOに戻して
# Developer Reply:
#
# ===========
#
# review：273
# Author Name:  Googleユーザー
# Review Date:  2019年2月26日
# Reviewer Ratings:  5
# Review Body:   好みの曲が、探せて良いですね🎵
# Developer Reply:
#
# ===========
#
# review：274
# Author Name:  Googleユーザー
# Review Date:  2019年1月24日
# Reviewer Ratings:  5
# Review Body:   いつも楽しく聞かせてもらってます
# Developer Reply:
#
# ===========
#
# review：275
# Author Name:  Googleユーザー
# Review Date:  2019年1月27日
# Reviewer Ratings:  5
# Review Body:   音楽は私の青春です！
# Developer Reply:
#
# ===========
#
# review：276
# Author Name:  かめさんりゅう
# Review Date:  2019年2月6日
# Reviewer Ratings:  5
# Review Body:   いつも、どこでも、スマホが使える所で お気に入りの曲を聞いてます。
# Developer Reply:
#
# ===========
#
# review：277
# Author Name:  Googleユーザー
# Review Date:  2019年2月9日
# Reviewer Ratings:  4
# Review Body:   おすすめのプレイリストが届くので、好みの曲が探しやすいです。
# Developer Reply:
#
# ===========
#
# review：278
# Author Name:  稲穂誠樹
# Review Date:  2019年1月22日
# Reviewer Ratings:  5
# Review Body:   満足できてます🎵
# Developer Reply:
#
# ===========
#
# review：279
# Author Name:  Takahiro Toyama
# Review Date:  2019年3月22日
# Reviewer Ratings:  3
# Review Body:   はえああた
# Developer Reply:
#
# ===========
#
# review：280
# Author Name:  Googleユーザー
# Review Date:  2019年3月30日
# Reviewer Ratings:  5
# Review Body:   なぁーんだ🍙ぜ
# Developer Reply:
#
# ===========
#
# review：281
# Author Name:  光男橋本
# Review Date:  2019年4月13日
# Reviewer Ratings:  5
# Review Body:   待受や自分で聴く為にいいき
# Developer Reply:
#
# ===========
#
# review：282
# Author Name:  田野博和
# Review Date:  2019年1月17日
# Reviewer Ratings:  5
# Review Body:   うたパス
# Developer Reply:
#
# ===========
#
# review：283
# Author Name:  平野正雄
# Review Date:  2019年4月16日
# Reviewer Ratings:  5
# Review Body:   楽しく聴かせてもらってます。
# Developer Reply:
#
# ===========
#
# review：284
# Author Name:  横山訓
# Review Date:  2019年3月15日
# Reviewer Ratings:  2
# Review Body:   なかなかダウンロードができません
# Developer Reply:
#
# ===========
#
# review：285
# Author Name:  なひとこなつ
# Review Date:  2019年1月21日
# Reviewer Ratings:  5
# Review Body:   使いやすくていい
# Developer Reply:
#
# ===========
#
# review：286
# Author Name:  Googleユーザー
# Review Date:  2019年1月19日
# Reviewer Ratings:  5
# Review Body:   日本語です
# ...
# Developer Reply:
#
# ===========
#
# review：628
# Author Name:  mmo NAGA
# Review Date:  2018年9月28日
# Reviewer Ratings:  1
# Review Body:   LISMO時代の方が格段に使いやすかったので、戻すか再び分離してほしいです。 ユーザーが求めているのはシンプルで使いやすいものです。 便利なのは良いことですが、機能を盛り込みすぎて落ちたり不便になるのでは本末転倒ではないでしょうか？
# Developer Reply:
#
# ===========
#
# review：629
# Author Name:  Googleユーザー
# Review Date:  2018年12月15日
# Reviewer Ratings:  1
# Review Body:   ハッキリ言いますがただのクソアプリですね。MAMALIVEが見たくて入れましたが全く繋がらない。10秒画像が繋がってればいい方ですね。すぐ真っ暗になってタブレットにもいれて試しましたがそちらでも観れず。時間の無駄でしたこんなアプリ二度と使いたくないなと。
# Developer Reply:
#
# ===========
#
# review：630
# Author Name:  aya honda
# Review Date:  2018年11月29日
# Reviewer Ratings:  1
# Review Body:   要らない機能が充実するたび、更新更新。本当にただのギガ泥棒。通信制限のとき本当にイライラする。結局オフラインのプレイヤー入れておかないと無いと不便。うたぱすやめようと思う。
# Developer Reply:
#
# ===========
#
# review：631
# Author Name:  Googleユーザー
# Review Date:  2018年10月1日
# Reviewer Ratings:  2
# Review Body:   ダウンロードの仕方が二通りあり混乱する。ごちゃごちゃしてて全体的に見づらくて仕方ない。通信速度落ちたら全然使えない。ダウンロードするときくらいしか使えない
# Developer Reply:
#
# ===========
#
# review：632
# Author Name:  這鹿作者様BigfaceAlien
# Review Date:  2018年8月2日
# Reviewer Ratings:  5
# Review Body:   なんだとぉぉぉ…( ﾟдﾟ)！ midi形式も一発で聴けるなら評価、 他の音楽アプリより工ｴｴｪｪ(´д｀)ｪｪｴｴ工♪
# 勝手にインストールされるのは嫌だけど、御主やりおるのぉ♪ こういうアプリを探していたのだよ。(≧∇≦) m(_
# _)mやっぱり要ります。評価下げて御免なさい。
# Developer Reply:
#
# ===========
#
# review：633
# Author Name:  三宅泰樹
# Review Date:  2018年8月3日
# Reviewer Ratings:  2
# Review Body:   歌詞の自動スクロールが使えません。あと、ジャケット画像がアルバムにある画像へ勝手に変わっています。その辺りを改善してくれると嬉しいです。端末はドコモのXperiaです。
# Developer Reply:
#
# ===========
#
# review：634
# Author Name:  Y-ma
# Review Date:  2019年3月30日
# Reviewer Ratings:  1
# Review Body:   LISMOでSDカードから本体のストレージに移動させたら、最近購入した楽曲以外なくなりました。機種換えする前から少しずつ集めたものなので非常に困ります。…ていうか、ふざけんなよ？集めてきた曲を大事にしていたのに。
# Developer Reply:
#
# ===========
#
# review：635
# Author Name:  とうからし
# Review Date:  2018年8月25日
# Reviewer Ratings:  1
# Review Body:   うたパスになってから車のBLUETOOTHで歌が聞けなくなった。LISMOの方が良かった。しかもアンインストールが出来ない！最悪！
# Developer Reply:
#
# ===========
#
# review：636
# Author Name:  のっつぉこぎ
# Review Date:  2019年3月8日
# Reviewer Ratings:  1
# Review Body:   いつの間にか聞けなくなっている。中古店で買うCDのほうが安い。
# Developer Reply:
#
# ===========
#
# review：637
# Author Name:  小暮ヨシエ
# Review Date:  2018年9月18日
# Reviewer Ratings:  1
# Review Body:   勝手に立ち上がってうざったい。しょっちゅうだからバッテリー喰うし。こんなの要らないからアンインストールしたいのにできないから更にうざったい！
# Developer Reply:
#
# ===========
#
# review：638
# Author Name:  ひょ子
# Review Date:  2018年8月26日
# Reviewer Ratings:  1
# Review Body:   勝手にプレーヤーが起動するようになって意味が解らん。つーかそもそもLISMOだけで良いのになんで要らん事したよ？
# Developer Reply:
#
# ===========
#
# review：639
# Author Name:  Googleユーザー
# Review Date:  2019年2月28日
# Reviewer Ratings:  1
# Review Body:   最低。知らない間に金取られてた
# Developer Reply:
#
# ===========
#
# review：640
# Author Name:  三出井
# Review Date:  2018年9月26日
# Reviewer Ratings:  1
# Review Body:   削除しても、更新通知がゾンビのごとく押し寄せるスパム。迷惑メールと同レベル。
# Developer Reply:
#
# ===========
#
# review：641
# Author Name:  泉卓哉
# Review Date:  2018年12月23日
# Reviewer Ratings:  5
# Review Body:   こんにちは。とても好きな曲。歌。を聞きたい時に聞く事が出来るのと好きなアーティスト。歌い手さんの曲が聞けるのがとても良いです。ありがとうございます。失礼します。
# Developer Reply:
#
# ===========
#
# review：642
# Author Name:  蘇露tanaka
# Review Date:  2019年2月2日
# Reviewer Ratings:  3
# Review Body:   聞き放題ができて 曲も少し安く買えるのはいいが 聞き放題できる曲が思ったより少ないのが 残念
# Developer Reply:
#
# ===========
#
# review：643
# Author Name:  秋月翡翠
# Review Date:  2019年4月21日
# Reviewer Ratings:  1
# Review Body:   なんで使いにくさ筆頭のうたパスを主体にしてしまったんですか………LISMOとうたパスとで別に分けてあったからユーザ側で自由に選択できたのに…… 逆だったらまだよかったのに……… LISMOをアップデートした途端長年これまで細かく作ってきたプレイリストが全て消滅してしまいました… 詳しく確認しようにもプレイリスト画面を再度開こうとする度に問題が起きて終了しましたと強制終了してしまいもはや楽曲の再生すらもままなりません……… 私の１５年分のデータが……また全部最初から作り直しですか…？ もう３桁はある全曲リストからひとつひとつ……？ LISMOを…LISMOを返して…… あんなにシンプルで使いやす...全文を表示なんで使いにくさ筆頭のうたパスを主体にしてしまったんですか………LISMOとうたパスとで別に分けてあったからユーザ側で自由に選択できたのに…… 逆だったらまだよかったのに……… LISMOをアップデートした途端長年これまで細かく作ってきたプレイリストが全て消滅してしまいました… 詳しく確認しようにもプレイリスト画面を再度開こうとする度に問題が起きて終了しましたと強制終了してしまいもはや楽曲の再生すらもままなりません……… 私の１５年分のデータが……また全部最初から作り直しですか…？ もう３桁はある全曲リストからひとつひとつ……？ LISMOを…LISMOを返して…… あんなにシンプルで使いやすくて長年ずっと重宝していたLISMOを返してください…（涙
# Developer Reply:
#
# ===========
#
# review：644
# Author Name:  masahiko yamada
# Review Date:  2018年11月18日
# Reviewer Ratings:  1
# Review Body:   うたぱすが悪さしてリスモのみの時代には不具合のなかった一曲がアップデート後(多分)、ブチブチとノイズが入るようになった。削除したいのですが。
# Developer Reply:
#
# ===========
#
# review：645
# Author Name:  Googleユーザー
# Review Date:  2018年9月14日
# Reviewer Ratings:  1
# Review Body:   消したいが何度消しても復活する
# Developer Reply:
#
# ===========
#
# review：646
# Author Name:  1248 aimo
# Review Date:  2019年4月15日
# Reviewer Ratings:  1
# Review Body:   以前購入した曲なのに忘れててもう一回取ってしまった時に二重にも三重にも課金させられているようなのですがなぜ『購入(ダウンロード)済みですもう一度購入しますか？』などの(親切な)案内がでて来ないのでしょうか？不親切だし使いづらいし一曲100円位で良いのに高くてただでさえぼったくりレベルで不信感や不満があるのに無駄な通知まできてうんざりなので早急に対応(通知停止)お願いします。あと、docomoが調子に乗ってサービス(対応と態度)が悪くなった20年位前のauという名前に変わる前のIDO？だった時からauを使ってますが(それからauが一位になった)ここ数年で金儲け主義になり売りだったサービス(対応)...全文を表示以前購入した曲なのに忘れててもう一回取ってしまった時に二重にも三重にも課金させられているようなのですがなぜ『購入(ダウンロード)済みですもう一度購入しますか？』などの(親切な)案内がでて来ないのでしょうか？不親切だし使いづらいし一曲100円位で良いのに高くてただでさえぼったくりレベルで不信感や不満があるのに無駄な通知まできてうんざりなので早急に対応(通知停止)お願いします。あと、docomoが調子に乗ってサービス(対応と態度)が悪くなった20年位前のauという名前に変わる前のIDO？だった時からauを使ってますが(それからauが一位になった)ここ数年で金儲け主義になり売りだったサービス(対応)も落ちてauに不満だらけなのでMNP予定です。かなり大人ですが見た目が童顔だからか新百×ヶ丘店の態度が悪い女店員が目について余計auに不満です。
# Developer Reply:
#
# ===========
#
# review：647
# Author Name:  Googleユーザー
# Review Date:  2019年4月24日
# Reviewer Ratings:  1
# Review Body:   最低。Lismoに戻してくれ。
# Developer Reply:
#
# ===========
#
# review：648
# Author Name:  吉田健一
# Review Date:  2018年8月2日
# Reviewer Ratings:  1
# Review Body:   auやめたのに更新だと恐いな？
# Developer Reply:
#
# ===========
#
# review：649
# Author Name:  Googleユーザー
# Review Date:  2019年3月19日
# Reviewer Ratings:  1
# Review Body:   聴きたい歌を検索して聴けないからやめようかと考えてる‼️
# Developer Reply:
#
# ===========
#
# review：650
# Author Name:  Googleユーザー
# Review Date:  2019年3月22日
# Reviewer Ratings:  1
# Review Body:   何故、うたパスとMusikStoreから取った曲と一緒にした意図が解らない❗Auの勝手で、利用者の気持ち考えてない❗アプリを評価、星ゼロがない。
# Developer Reply:
#
# ===========
#
# review：651
# Author Name:  菊池太一
# Review Date:  2019年3月2日
# Reviewer Ratings:  1
# Review Body:   聞けない曲が出たり、起動が遅い聞きたい曲だけDLしたらアンインストールする。
# Developer Reply:
#
# ===========
#
# review：652
# Author Name:  Googleユーザー
# Review Date:  2019年1月1日
# Reviewer Ratings:  1
# Review Body:   毎回ダウンロード❔しないと聞けない‼あり得ない　最低‼
# Developer Reply:
#
# ===========
#
# review：653
# Author Name:  Googleユーザー
# Review Date:  2019年1月4日
# Reviewer Ratings:  1
# Review Body:   障害者には必要ないです(>_<)？プライバシーが怖いです😂
# Developer Reply:
#
# ===========
#
# review：654
# Author Name:  神谷基
# Review Date:  2019年1月18日
# Reviewer Ratings:  3
# Review Body:   良くも、悪くもない、気分転換 人は世につれ、唄につれ。
# Developer Reply:
#
# ===========
#
# review：655
# Author Name:  Googleユーザー
# Review Date:  2018年11月8日
# Reviewer Ratings:  1
# Review Body:   使わないのでアンインストールしたのに何度も何度も勝手にインストールされる　邪魔
# Developer Reply:
#
# ===========
#
# review：656
# Author Name:  Googleユーザー
# Review Date:  2019年2月24日
# Reviewer Ratings:  1
# Review Body:   プレイリストだけで良い‼️容量の問題！ごめんなさい
# Developer Reply:
#
# ===========
#
# review：657
# Author Name:  勝俣聡嗣
# Review Date:  2019年4月9日
# Reviewer Ratings:  2
# Review Body:   利用する意志が無いのにしつこい❗
# Developer Reply:
#
# ===========
#
# review：658
# Author Name:  佐藤福則
# Review Date:  2019年4月14日
# Reviewer Ratings:  1
# Review Body:   使用しないので分からない。
# Developer Reply:
#
# ===========
#
# review：659
# Author Name:  おおかわよしお
# Review Date:  2019年2月25日
# Reviewer Ratings:  1
# Review Body:   アンインストールしても勝手にアプデするしつこく悪質
# Developer Reply:
#
# ===========
#
# review：660
# Author Name:  t h
# Review Date:  2018年9月30日
# Reviewer Ratings:  1
# Review Body:   ごみ。デフォルトでこんなの入っていても使わないしいらない。
# Developer Reply:
#
# ===========
#
# review：661
# Author Name:  吉野雅子
# Review Date:  2018年10月23日
# Reviewer Ratings:  2
# Review Body:   前のLISMOの方が良かったです。
# Developer Reply:
#
# ===========
#
# review：662
# Author Name:  katchan slump
# Review Date:  2019年4月12日
# Reviewer Ratings:  1
# Review Body:   以前のレビューが消えてる。 プレイリストだけでは飽きたらなかったのか・・・
# Developer Reply:
#
# ===========
#
# review：663
# Author Name:  maghreb yamada
# Review Date:  2018年12月1日
# Reviewer Ratings:  1
# Review Body:   勝手にダウンロードするな 凄い迷惑 くだらない
# Developer Reply:
#
# ===========
#
# review：664
# Author Name:  nami daimon
# Review Date:  2019年4月15日
# Reviewer Ratings:  2
# Review Body:   今日(4/15)突然途中で止まるようになりました。なんでですか？😞
# Developer Reply:
#
# ===========
#
# review：665
# Author Name:  西村京
# Review Date:  2018年8月3日
# Reviewer Ratings:  1
# Review Body:   勝手にインストールは止めてください。
# Developer Reply:
#
# ===========
#
# review：666
# Author Name:  Googleユーザー
# Review Date:  2019年1月24日
# Reviewer Ratings:  1
# Review Body:   いらない、使えない、容量喰うのゴミ
# Developer Reply:
#
# ===========
#
# review：667
# Author Name:  Googleユーザー
# Review Date:  2018年8月3日
# Reviewer Ratings:  5
# Review Body:   勝手に更新されましたが、たくさんの気に入るアーティストのうたを聞けるからファイブスター
# Developer Reply:
#
# ===========
#
# review：668
# Author Name:  青木俊夫
# Review Date:  2018年10月31日
# Reviewer Ratings:  1
# Review Body:   よくわからない
# Developer Reply:
#
# ===========
#
# review：669
# Author Name:  松田充
# Review Date:  2018年11月23日
# Reviewer Ratings:  1
# Review Body:   勝手に更新かかるとかあり得ない
# Developer Reply:
#
# ===========
#
# review：670
# Author Name:  Googleユーザー
# Review Date:  2018年8月14日
# Reviewer Ratings:  2
# Review Body:   やり方分かりにくいし前の方が使いやすかった
# Developer Reply:
#
# ===========
#
# review：671
# Author Name:  山岸卓也
# Review Date:  2018年9月28日
# Reviewer Ratings:  2
# Review Body:   イヤホンを付けてたら勝手に音が鳴る。
# Developer Reply:
#
# ===========
#
# review：672
# Author Name:  康仁塩島
# Review Date:  2018年8月3日
# Reviewer Ratings:  1
# Review Body:   おまえの消しか方教えろ。
# Developer Reply:
#
# ===========
#
# review：673
# Author Name:  Googleユーザー
# Review Date:  2018年11月12日
# Reviewer Ratings:  1
# Review Body:   検索したやつでてこないし、正直このアプリ使わないので早くアンストしたい。
# Developer Reply:
#
# ===========
#
# review：674
# Author Name:  椛†竜菜琴啓
# Review Date:  2018年10月28日
# Reviewer Ratings:  1
# Review Body:   いらない　なぜアンインストールできない‼
# Developer Reply:
#
# ===========
#
# review：675
# Author Name:  Googleユーザー
# Review Date:  2019年2月2日
# Reviewer Ratings:  5
# Review Body:   とっても便利いいです。共有しやすいです。
# Developer Reply:
#
# ===========
#
# review：676
# Author Name:  さゆおか
# Review Date:  2019年4月14日
# Reviewer Ratings:  2
# Review Body:   プレイリストに入れた曲が消えてしまいます、前のLISMOのほうが好きでした
# Developer Reply:
#
# ===========
#
# review：677
# Author Name:  フリーダ
# Review Date:  2018年8月3日
# Reviewer Ratings:  1
# Review Body:   勝手にインストールとかうざい。
# Developer Reply:
#
# ===========
#
# review：678
# Author Name:  TAKU
# Review Date:  2018年8月10日
# Reviewer Ratings:  1
# Review Body:   アンインストールを出来るようにしろ！
# Developer Reply:
#
# ===========
#
# review：679
# Author Name:  小川徹
# Review Date:  2018年9月8日
# Reviewer Ratings:  1
# Review Body:   以前のLISMOが分かりやすくてよかったのに
# Developer Reply:
#
# ===========
#
# review：680
# Author Name:  幾野昌代
# Review Date:  2019年4月19日
# Reviewer Ratings:  3
# Review Body:   五木ひろし
# Developer Reply:
#
# ===========
#
# review：681
# Author Name:  Googleユーザー
# Review Date:  2019年3月29日
# Reviewer Ratings:  5
# Review Body:   役にたちました
# Developer Reply:
#
# ===========
#
# review：682
# Author Name:  Googleユーザー
# Review Date:  2019年3月14日
# Reviewer Ratings:  5
# Review Body:   これに決めてます。
# Developer Reply:
#
# ===========
#
# review：683
# Author Name:  東珠美
# Review Date:  2018年8月8日
# Reviewer Ratings:  2
# Review Body:   ジャニーズ系の曲がないからから揚げ退会をします!
# Developer Reply:
#
# ===========
#
# review：684
# Author Name:  Googleユーザー
# Review Date:  2018年12月19日
# Reviewer Ratings:  5
# Review Body:   うたぱす購入する
# Developer Reply:
#
# ===========
#
# review：685
# Author Name:  駒宮泰春
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   ワールドビジョン2019.komamiyayasuharu
# Developer Reply:
#
# ===========
#
# review：686
# Author Name:  fumika t
# Review Date:  2019年1月19日
# Reviewer Ratings:  1
# Review Body:   削除させてほしい
# Developer Reply:
#
# ===========
#
# review：687
# Author Name:  Googleユーザー
# Review Date:  2018年10月28日
# Reviewer Ratings:  1
# Review Body:   無くなって欲しい
# Developer Reply:
#
# ===========
#
# review：688
# Author Name:  SUSUMU IDA
# Review Date:  2018年10月9日
# Reviewer Ratings:  1
# Review Body:   アンインストール出来ない
# Developer Reply:
#
# ===========
#
# review：689
# Author Name:  Googleユーザー
# Review Date:  2019年1月7日
# Reviewer Ratings:  3
# Review Body:   多少は、楽しめます!ただ、歌手や曲が少ないです!
# Developer Reply:
#
# ===========
#
# review：690
# Author Name:  私はひろみ
# Review Date:  2019年4月23日
# Reviewer Ratings:  2
# Review Body:   Bluetoothで飛んでくれないからいらない
# Developer Reply:
#
# ===========
#
# review：691
# Author Name:  佐藤栄司
# Review Date:  2019年1月26日
# Reviewer Ratings:  1
# Review Body:   通知がじゃま。
# Developer Reply:
#
# ===========
#
# review：692
# Author Name:  齊藤千里
# Review Date:  2019年2月10日
# Reviewer Ratings:  1
# Review Body:   いらない。
# Developer Reply:
#
# ===========
#
# review：693
# Author Name:  Михаил Михайлович
# Review Date:  2018年10月3日
# Reviewer Ratings:  1
# Review Body:   ｺﾞﾐｸｽﾞ過ぎる 非常に邪魔 要らない
# Developer Reply:
#
# ===========
#
# review：694
# Author Name:  Googleユーザー
# Review Date:  2018年8月5日
# Reviewer Ratings:  1
# Review Body:   いらない
# Developer Reply:
#
# ===========
#
# review：695
# Author Name:  はる
# Review Date:  2018年8月13日
# Reviewer Ratings:  1
# Review Body:   必要ない
# Developer Reply:
#
# ===========
#
# review：696
# Author Name:  菱田行雄
# Review Date:  2018年8月26日
# Reviewer Ratings:  5
# Review Body:   菱田行雄
# Developer Reply:
#
# ===========
#
# review：697
# Author Name:  コメント欄に爆裂魔法を撃って登録者が何人増えるのか
# Review Date:  2019年4月15日
# Reviewer Ratings:  1
# Review Body:   ふん。
# Developer Reply:
#
# ===========
#
# review：698
# Author Name:  畠山未麗
# Review Date:  2019年4月13日
# Reviewer Ratings:  5
# Review Body:   金額が怖い
# Developer Reply:
#
# ===========
#
# review：699
# Author Name:  千阪昌幸
# Review Date:  2019年3月25日
# Reviewer Ratings:  5
# Review Body:   いつもありがとうございます☀
# Developer Reply:
#
# ===========
#
# review：700
# Author Name:  Googleユーザー
# Review Date:  2018年11月1日
# Reviewer Ratings:  4
# Review Body:   良いアプリですね
# Developer Reply:
#
# ===========
#
# review：701
# Author Name:  由美清水
# Review Date:  2019年3月31日
# Reviewer Ratings:  5
# Review Body:   競馬のサウンドやっぱり私は
# Developer Reply:
#
# ===========
#
# review：702
# Author Name:  Googleユーザー
# Review Date:  2018年12月14日
# Reviewer Ratings:  5
# Review Body:   ありがとう。
# Developer Reply:
#
# ===========
#
# review：703
# Author Name:  コベンハナコ
# Review Date:  2018年12月5日
# Reviewer Ratings:  5
# Review Body:   難しくなく、選びやすい
# Developer Reply:
#
# ===========
#
# review：704
# Author Name:  Googleユーザー
# Review Date:  2018年12月1日
# Reviewer Ratings:  5
# Review Body:   一緒
# Developer Reply:
#
# ===========
#
# review：705
# Author Name:  Googleユーザー
# Review Date:  2019年3月13日
# Reviewer Ratings:  5
# Review Body:   とても良かったです🍀
# Developer Reply:
#
# ===========
#
# review：706
# Author Name:  少佐Masa
# Review Date:  2018年8月11日
# Reviewer Ratings:  1
# Review Body:   邪魔
# Developer Reply:
#
# ===========
#
# review：707
# Author Name:  小野啓一
# Review Date:  2018年8月3日
# Reviewer Ratings:  1
# Review Body:   うとしい
# Developer Reply:
#
# ===========
#
# review：708
# Author Name:  久保田瑞弥
# Review Date:  2019年3月14日
# Reviewer Ratings:  3
# Review Body:   とても良かった
# Developer Reply:
#
# ===========
#
# review：709
# Author Name:  aki kawa
# Review Date:  2018年10月13日
# Reviewer Ratings:  1
# Review Body:   ない
# Developer Reply:
#
# ===========
#
# review：710
# Author Name:  愛子対比地
# Review Date:  2019年3月31日
# Reviewer Ratings:  3
# Review Body:   もう少し
# Developer Reply:
#
# ===========
#
# review：711
# Author Name:  横山治
# Review Date:  2019年4月16日
# Reviewer Ratings:  5
# Review Body:   使わない
# Developer Reply:
#
# ===========
#
# review：712
# Author Name:  ワカタビタカユキ
# Review Date:  2018年10月5日
# Reviewer Ratings:  1
# Review Body:   え、いる？
# Developer Reply:
#
# ===========
#
# review：713
# Author Name:  Googleユーザー
# Review Date:  2018年9月27日
# Reviewer Ratings:  4
# Review Body:   使いやすい
# Developer Reply:
#
# ===========
#
# review：714
# Author Name:  Googleユーザー
# Review Date:  2018年9月27日
# Reviewer Ratings:  4
# Review Body:   良い‼️
# Developer Reply:
#
# ===========
#
# review：715
# Author Name:  むちもも
# Review Date:  2019年2月12日
# Reviewer Ratings:  1
# Review Body:   残念
# Developer Reply:
#
# ===========
#
# review：716
# Author Name:  Googleユーザー
# Review Date:  2019年3月3日
# Reviewer Ratings:  1
# Review Body:   やめ
# Developer Reply:
#
# ===========
#
# review：717
# Author Name:  Googleユーザー
# Review Date:  2019年3月26日
# Reviewer Ratings:  3
# Review Body:   Good👍
# Developer Reply:
#
# ===========
#
# review：718
# Author Name:  下ネタ番長
# Review Date:  2018年10月21日
# Reviewer Ratings:  1
# Review Body:   最低
# Developer Reply:
#
# ===========
#
# review：719
# Author Name:  Googleユーザー
# Review Date:  2019年3月18日
# Reviewer Ratings:  5
# Review Body:   素晴らしい
# Developer Reply:
#
# ===========
#
# review：720
# Author Name:  西口薫
# Review Date:  2019年3月30日
# Reviewer Ratings:  5
# Review Body:   楽しい
# Developer Reply:
#
# ===========
#
# review：721
# Author Name:  Googleユーザー
# Review Date:  2019年3月24日
# Reviewer Ratings:  5
# Review Body:   すごい。(^-^)/
# Developer Reply:
#
# ===========
#
# review：722
# Author Name:  鈴木純明
# Review Date:  2019年3月30日
# Reviewer Ratings:  5
# Review Body:   ＼(^_^)／(´ま(^_^;)＼(^_^)／Д｀)((((；゜Д゜)))
# Developer Reply:
