# %%
cd /anaconda3/envs/nlp/lib/python3.7/site-packages
# Out:
# /anaconda3/envs/nlp/lib/python3.7/site-packages

# %%
import time
from bs4 import BeautifulSoup
import sys, io
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.proxy import *
import pandas as pd

# %%
import MeCab
from os import path
import neologdn
import re
import emoji

pos_list = [10, 11, 31, 32, 34]
pos_list.extend(list(range(36,50)))
pos_list.extend([59, 60, 62, 67])

def create_mecab_list(text):
    mecab_list = []
    mecab = MeCab.Tagger("-Ochasen")
    mecab.parse("")
    # encoding = text.encode('utf-8')
    node = mecab.parseToNode(text)
    while node:
        if len(node.surface) > 1:
            if node.posid in pos_list:
                morpheme = node.surface
                mecab_list.append(morpheme)
        node = node.next
    return mecab_list

def give_emoji_free_text(text):
    allchars = [str for str in text]
    emoji_list = [c for c in allchars if c in emoji.UNICODE_EMOJI]
    cleaned_text = ' '.join([str for str in text.split() if not any(i in str for i in emoji_list)])
    return cleaned_text

def clean_text(text):
    text = give_emoji_free_text(text)
    text = neologdn.normalize(text)
    text = create_mecab_list(text)    
    return text

# %%
no_of_reviews = 1000
non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

# %%
from selenium.common.exceptions import NoSuchElementException        
def check_exists_by_xpath(xpath):
    try:
        driver.find_element_by_xpath(xpath)
    except NoSuchElementException:
        return False
    return True
reviews = pd.DataFrame(columns = ["review", "Author Name", "Review Date", "Review Ratings", 
                                  "Review Body", "Developer Reply"])
temp = {"review": 0, "Author Name": "", "Review Date": "", "Review Ratings": 0, 
        "Review Body": "", "Developer Reply": ""}

def replace_value_with_definition(key_to_find, definition):
    for key in temp.keys():
        if key == key_to_find:
            temp[key] = definition

# %%
cd ~/Desktop/chrome
# Out:
# /Users/justinwang/Desktop/chrome

# %%
driver = webdriver.Chrome(r"./chromedriver")

# %%
wait = WebDriverWait( driver, 10 )

# %%
# Append your app store urls here
urls = ["https://play.google.com/store/apps/details?id=com.kddi.android.UtaPass&hl=ja"]

for url in urls:

    driver.get(url)

    page = driver.page_source

    soup_expatistan = BeautifulSoup(page, "html.parser")

    expatistan_table = soup_expatistan.find("h1", class_="AHFaub")

    print("App name: ", expatistan_table.string)

    expatistan_table = soup_expatistan.findAll("span", class_="htlgb")[4]

    print("Installs Range: ", expatistan_table.string)

    expatistan_table = soup_expatistan.find("meta", itemprop="ratingValue")

    print("Rating Value: ", expatistan_table['content'])

    expatistan_table = soup_expatistan.find("meta", itemprop="reviewCount")

    print("Reviews Count: ", expatistan_table['content'])

    soup_histogram = soup_expatistan.find("div", class_="VEF2C")

    rating_bars = soup_histogram.find_all('div', class_="mMF0fd")

    for rating_bar in rating_bars:
        print("Rating: ", rating_bar.find("span").text)
        print("Rating count: ", rating_bar.find("span", class_="L2o20d").get('title'))

    # open all reviews
    url = url + '&showAllReviews=true'
    driver.get(url)
    time.sleep(5) # wait dom ready
    for i in range(1,25):
        try:
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);') # scroll to load other reviews
            time.sleep(2)
            if check_exists_by_xpath('//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div[1]/div/div/div[1]/div[2]/div[2]/div/content/span'):
                driver.find_element_by_xpath('//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div[1]/div/div/div[1]/div[2]/div[2]/div/content/span').click()
                time.sleep(2)
        except:
            pass

    page = driver.page_source

    soup_expatistan = BeautifulSoup(page, "html.parser")
    expand_pages = soup_expatistan.findAll("div", class_="d15Mdf")
    counter = 1
    items = []
    
    for expand_page in expand_pages:
        try:
            # print("\n===========\n")
            
            # print("review：" + str(counter))
            review = str(counter)
            
            # print("Author Name: ", str(expand_page.find("span", class_="X43Kjb").text))
            Author_Name = str(expand_page.find("span", class_="X43Kjb").text)
            
            # print("Review Date: ", expand_page.find("span", class_="p2TkOb").text)
            Review_Date = str(expand_page.find("span", class_="p2TkOb").text)
            
            '''
            //didn't find reviewer link
            print("Reviewer Link: ", expand_page.find("a", class_="reviews-permalink")['href'])
            '''
            
            reviewer_ratings = expand_page.find("div", class_="pf5lIe").find_next()['aria-label'];
            reviewer_ratings = reviewer_ratings.split('/')[0]
            reviewer_ratings = ''.join(x for x in reviewer_ratings if x.isdigit())
            # print("Reviewer Ratings: ", reviewer_ratings)
            Reviewer_Ratings = int(reviewer_ratings)
            
            '''
            //didn't find review title
            print("Review Title: ", str(expand_page.find("span", class_="review-title").string))
            '''
            
            # print("Review Body: ", str(expand_page.find("div", class_="UD7Dzf").text))
            Review_Body = str(expand_page.find("div", class_="UD7Dzf").text)
            Review_Body_cleaned = clean_text(Review_Body)
            Review_Body_string = ''.join(Review_Body_cleaned)
            
            developer_reply = expand_page.find_parent().find("div", class_="LVQB0b")
            if hasattr(developer_reply, "text"):
                # print("Developer Reply: " + "\n", str(developer_reply.text))
                Developer_Reply = str(developer_reply.text)
            else:
                # print("Developer Reply: ", "")
                Developer_Reply = ""
            
            counter += 1           
            item = {
                    "review": counter - 1,
                    "Author Name": Author_Name,
                    "Reviewer Ratings": Reviewer_Ratings,
                    "Review Date": Review_Date,
                    "Review Body": Review_Body_string,
                    "Developer Reply": Developer_Reply
                    }
            items.append(item)
                
        except:
            pass
driver.quit()
# df = pd.DataFrame(items, columns=["review", "Author Name", "Reviewer Ratings", "Review Date", "Review Body", "Developer Reply"])
# Out:
# App name:  うたパス
# Installs Range:  1,000,000+
# Rating Value:  3.464590549468994
# Reviews Count:  2344
# Rating:  5
# Rating count:  None
# Rating:  4
# Rating count:  None
# Rating:  3
# Rating count:  None
# Rating:  2
# Rating count:  None
# Rating:  1
# Rating count:  None

# %%
df = pd.DataFrame(items, columns = ["review", "Author Name", "Review Date", "Reviewer Ratings", 
                                    "Review Body", "Developer Reply"])
df
# Out:
#      review      Author Name  Review Date  Reviewer Ratings  \
# 0         1             横田直樹    2019年5月3日                 2
# 1         2             ゆきゆき    2019年5月1日                 1
# 2         3            s tat   2019年4月30日                 1
# 3         4    NISHII YASUKO   2019年4月29日                 1
# 4         5          kimi oh    2019年5月4日                 1
# 5         6             松尾聖子    2019年5月2日                 3
# 6         7       Googleユーザー   2019年4月20日                 1
# 7         8            MA CA   2019年4月18日                 2
# 8         9              佃隆宏   2019年4月26日                 4
# 9        10             にしえみ   2019年4月23日                 2
# 10       11             Yuya   2019年4月25日                 1
# 11       12             おかとも   2019年4月30日                 1
# 12       13              宝くじ    2019年5月5日                 1
# 13       14             ここここ   2019年4月20日                 1
# 14       15              狼音牙   2019年4月22日                 1
# 15       16              岩田将   2019年3月29日                 1
# 16       17         toi moko   2019年4月15日                 1
# 17       18  Takashi Yoshida   2019年4月15日                 2
# 18       19              久渚直   2019年3月31日                 2
# 19       20         ウォーカーアレン   2019年4月30日                 1
# 20       21              髭本鎮   2019年3月25日                 4
# 21       22     snow phantom   2019年2月17日                 1
# 22       23       Googleユーザー   2019年2月27日                 1
# 23       24        マルクスジョナサン   2019年4月24日                 1
# 24       25               黒澤   2019年3月13日                 2
# 25       26      ぶるーべりぃsachi   2019年4月25日                 5
# 26       27             北尾康太    2019年4月4日                 2
# 27       28              成瀬昶   2019年3月15日                 1
# 28       29       Googleユーザー   2019年2月25日                 1
# 29       30               ゆ。    2019年3月3日                 5
# ..      ...              ...          ...               ...
# 755     756       Googleユーザー    2018年8月3日                 5
# 756     757       Googleユーザー   2018年8月14日                 2
# 757     758             康仁塩島    2018年8月3日                 1
# 758     759             フリーダ    2018年8月3日                 1
# 759     760             TAKU   2018年8月10日                 1
# 760     761              小川徹    2018年9月8日                 1
# 761     762              東珠美    2018年8月8日                 2
# 762     763             幾野昌代   2019年4月19日                 3
# 763     764             齊藤千里   2019年2月10日                 1
# 764     765       Googleユーザー    2018年8月5日                 1
# 765     766               はる   2018年8月13日                 1
# 766     767             菱田行雄   2018年8月26日                 5
# 767     768             げすぼぉ   2019年4月15日                 1
# 768     769             千阪昌幸   2019年3月25日                 5
# 769     770       Googleユーザー  2018年12月14日                 5
# 770     771       Googleユーザー   2018年12月1日                 5
# 771     772           少佐Masa   2018年8月11日                 1
# 772     773             小野啓一    2018年8月3日                 1
# 773     774         aki kawa  2018年10月13日                 1
# 774     775            愛子対比地   2019年3月31日                 3
# 775     776              横山治   2019年4月16日                 5
# 776     777         ワカタビタカユキ   2018年10月5日                 1
# 777     778       Googleユーザー   2018年9月27日                 4
# 778     779       Googleユーザー   2018年9月27日                 4
# 779     780             むちもも   2019年2月12日                 1
# 780     781       Googleユーザー    2019年3月3日                 1
# 781     782       Googleユーザー   2019年3月26日                 3
# 782     783            下ネタ番長  2018年10月21日                 1
# 783     784       Googleユーザー   2019年3月18日                 5
# 784     785              西口薫   2019年3月30日                 5
#
#                                            Review Body Developer Reply
# 0    歌詞見れるいいずれ誤字あるあとお気に入りプレイリスト開くライブラリ更新リセットれるマジ入れラ...
# 1    通知切る方法分かりすぎる見る新たアプリ入れ通知切れ判明アプリ開発若者毎日アクティブ新曲買っ聴...
# 2    どうしてもLISMO比べダウンロード反映LISMO動画一覧表示パス分離とにかく使いLISMO...
# 3      以前購入機種だぶっダウンロードれる消す出来機種するダウンロード出来有るガラケー購入スマ出来有り
# 4    LISMOライブラリ開けなっ愛着あっLISMO使っ消し下らないうたパスLISMOいらついて最...
# 5
# 6    au端末シムフリー端末使用au端末反応鈍くタッチ再生かかるシムフリー端末プレイリスト音楽消え...
# 7          起動重い音楽聞いバックグラウンドアプリ消し音楽聞けバックグラウンド使え結構愛用もういら
# 8                                      アルバム音量あげさげ-★ひとつ
# 9                        購入楽曲購入流れる聞き購入楽曲聞い聞け聞こする操作必要なる
# 10                     様々不具合対応起きトラブルそれ以前挙げ評価記載ありいつ改善思っ
# 11               LISMO良かっ使い勝手悪くなりプレーヤーバックグラウンド再生それできなっ
# 12       lismo代わりできゴミアプリ遅いわかり払うauユーザーサービス低下アプリauアプリ多かっ
# 13                           使いダウンロードらい無駄機能ビデオ再生する余計使い
# 14                           LISMO使えなっ早くもどせうたパスLISMO使い
# 15   正直辛いLISMOガラケー使っ今さら新しく使えワケわからアプリ作る必要あっ疑問プレイリスト消...
# 16   本当にうたパスLISMO統合疑問思うLISMO使いロード短い保存指定出来うたパスロード長く保...
# 17   聴き利用プレイヤー評価好きデザインお洒落歌詞見れる楽曲アルバム一覧読み仮名ソートれる嫌いアル...
# 18   いまいち使い勝手悪いプリインストールLISMOない代わり仕方使っ間違え再生アルバム再生履歴消...
# 19                             何でLISMOなく?)ただただ使いめんどくさい
# 20   以前使っLISMOレイアウト見易く操作一覧削除選ぶあるスライドバーちょくちょく反応以前ましな...
# 21   LISMO重い更新遅い外部入れ聴けあるLISMO使えるアプリ介さ使え要ら情報テロップ言えるプ...
# 22
# 23                        バックグラウンド再生できなっもう要ら色々ダウンロード詐欺
# 24   歌詞表示ちゃんと出来カラオケ表示対応自動スクロール対応機能プレイリスト楽曲入れる歌詞変わるも...
# 25                毎日使っ歌詞見れるカラオケ練習便利キレイテーマ決め聞きフォルダ作れる活用
# 26   取り種類まあ程度納得操作イマイチプレイリスト簡単できる評価良い通信途切れするいちいちログイン...
# 27   今日20190313新しくMusicstore購入DLLISMOリスト更新DL確認変わらMu...
# 28   こいつリスモプレイヤー使っアプ承諾なし削除なに考え悪質悪辣最低最悪企業あり対応これ料金高い云...
# 29   好きアーティスト聴ける気分変えれるジャンルある楽しみ出来る324シャッフル再生スキップ出来る...
# ..                                                 ...             ...
# 755                       勝手更新たくさん入るアーティストうた聞けるファイブスター
# 756                                           やり方分かり使い
# 757                                           おまえ消し教えろ
# 758                                       勝手インストールかうざい
# 759                                      アンインストール出来るしろ
# 760                                         以前LISMO分かり
# 761                                        ジャニーズない揚げ退会
# 762                                              五木ひろし
# 763                                                 いら
# 764                                                 いら
# 765                                               必要ない
# 766                                               菱田行雄
# 767
# 768
# 769
# 770                                                 一緒
# 771                                                 邪魔
# 772                                                としい
# 773                                                 ない
# 774
# 775                                                 使わ
# 776                                                 いる
# 777                                                 使い
# 778
# 779                                                 残念
# 780                                                 やめ
# 781
# 782                                                 最低
# 783                                              素晴らしい
# 784                                                楽しい
#
# [785 rows x 6 columns]

# %%
import numpy as np
df['Review Body'].replace('', np.nan, inplace=True)
df.dropna(subset=['Review Body'], inplace=True)
df.head()
# Out:
#    review    Author Name Review Date  Reviewer Ratings  \
# 0       1           横田直樹   2019年5月3日                 2
# 1       2           ゆきゆき   2019年5月1日                 1
# 2       3          s tat  2019年4月30日                 1
# 3       4  NISHII YASUKO  2019年4月29日                 1
# 4       5        kimi oh   2019年5月4日                 1
#
#                                          Review Body Developer Reply
# 0  歌詞見れるいいずれ誤字あるあとお気に入りプレイリスト開くライブラリ更新リセットれるマジ入れラ...
# 1  通知切る方法分かりすぎる見る新たアプリ入れ通知切れ判明アプリ開発若者毎日アクティブ新曲買っ聴...
# 2  どうしてもLISMO比べダウンロード反映LISMO動画一覧表示パス分離とにかく使いLISMO...
# 3    以前購入機種だぶっダウンロードれる消す出来機種するダウンロード出来有るガラケー購入スマ出来有り
# 4  LISMOライブラリ開けなっ愛着あっLISMO使っ消し下らないうたパスLISMOいらついて最...

# %%
cd ~/Desktop
# Out:
# /Users/justinwang/Desktop

# %%
df.to_csv("GooglePlayReviews.csv", columns = ["review", "Author Name", "Review Date", "Reviewer Ratings", 
          "Review Body", "Developer Reply"], na_rep = 'NA')
